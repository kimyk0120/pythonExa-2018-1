# %%
import pandas as pd

# %%
pd.read_excel("../data/01_Population_Seoul.xls")
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>기간</th>
#       <th>자치구</th>
#       <th>세대</th>
#       <th>인구</th>
#       <th>인구.1</th>
#       <th>인구.2</th>
#       <th>인구.3</th>
#       <th>인구.4</th>
#       <th>인구.5</th>
#       <th>인구.6</th>
#       <th>인구.7</th>
#       <th>인구.8</th>
#       <th>세대당인구</th>
#       <th>65세이상고령자</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>기간</td>
#       <td>자치구</td>
#       <td>세대</td>
#       <td>합계</td>
#       <td>합계</td>
#       <td>합계</td>
#       <td>한국인</td>
#       <td>한국인</td>
#       <td>한국인</td>
#       <td>등록외국인</td>
#       <td>등록외국인</td>
#       <td>등록외국인</td>
# ...

# %%
pd.read_excel("../data/01_Population_Seoul.xls", header=2)  
# 3번째 행이 데이터의 header 라는 의미
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>기간</th>
#       <th>자치구</th>
#       <th>세대</th>
#       <th>계</th>
#       <th>남자</th>
#       <th>여자</th>
#       <th>계.1</th>
#       <th>남자.1</th>
#       <th>여자.1</th>
#       <th>계.2</th>
#       <th>남자.2</th>
#       <th>여자.2</th>
#       <th>세대당인구</th>
#       <th>65세이상고령자</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2018.2/4</td>
#       <td>합계</td>
#       <td>4241547</td>
#       <td>10089517</td>
#       <td>4935944</td>
#       <td>5153573</td>
#       <td>9814049</td>
#       <td>4802769</td>
#       <td>5011280</td>
#       <td>275468</td>
# ...

# %%
pd.read_excel("../data/01_Population_Seoul.xls", header=2, usecols="B,D:N")
# B 열, D열 부터 N열
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>자치구</th>
#       <th>계</th>
#       <th>남자</th>
#       <th>여자</th>
#       <th>계.1</th>
#       <th>남자.1</th>
#       <th>여자.1</th>
#       <th>계.2</th>
#       <th>남자.2</th>
#       <th>여자.2</th>
#       <th>세대당인구</th>
#       <th>65세이상고령자</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>합계</td>
#       <td>10089517</td>
#       <td>4935944</td>
#       <td>5153573</td>
#       <td>9814049</td>
#       <td>4802769</td>
#       <td>5011280</td>
#       <td>275468</td>
#       <td>133175</td>
#       <td>142293</td>
#       <td>2.31</td>
#       <td>1393671</td>
#     </tr>
# ...

# %%
pd.read_excel("../data/01_Population_Seoul.xls", header=2, usecols="B,D:N", skipfooter=0)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>자치구</th>
#       <th>계</th>
#       <th>남자</th>
#       <th>여자</th>
#       <th>계.1</th>
#       <th>남자.1</th>
#       <th>여자.1</th>
#       <th>계.2</th>
#       <th>남자.2</th>
#       <th>여자.2</th>
#       <th>세대당인구</th>
#       <th>65세이상고령자</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>합계</td>
#       <td>10089517</td>
#       <td>4935944</td>
#       <td>5153573</td>
#       <td>9814049</td>
#       <td>4802769</td>
#       <td>5011280</td>
#       <td>275468</td>
#       <td>133175</td>
#       <td>142293</td>
#       <td>2.31</td>
#       <td>1393671</td>
#     </tr>
# ...

# %%
col_names = ["구", "인구수", "남성", "여성", "내국인", "남성내국인", "여성내국인", "외국인", "남성외국인", "여성외국인"
    , "세대당인구", "고령자"]

# %%
pd.read_excel("../data/01_Population_Seoul.xls", header=2, usecols="B,D:N", skipfooter=0, names=col_names)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>구</th>
#       <th>인구수</th>
#       <th>남성</th>
#       <th>여성</th>
#       <th>내국인</th>
#       <th>남성내국인</th>
#       <th>여성내국인</th>
#       <th>외국인</th>
#       <th>남성외국인</th>
#       <th>여성외국인</th>
#       <th>세대당인구</th>
#       <th>고령자</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>합계</td>
#       <td>10089517</td>
#       <td>4935944</td>
#       <td>5153573</td>
#       <td>9814049</td>
#       <td>4802769</td>
#       <td>5011280</td>
#       <td>275468</td>
#       <td>133175</td>
#       <td>142293</td>
#       <td>2.31</td>
#       <td>1393671</td>
#     </tr>
# ...

# %%
raw_data = pd.read_excel("../data/01_Population_Seoul.xls", header=2, usecols="B,D:N", skipfooter=0, names=col_names)

# %%
raw_data["구"].unique()
# Out:
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'], dtype=object)

# %%
raw_data.drop(0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-ee2ad5099c86> in <module>()
# ----> 1 raw_data.drop(0, inplace=True)
#       2 raw_data.info()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3106         for axis, labels in axes.items():
#    3107             if labels is not None:
# ...

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 1 to 25
# Data columns (total 12 columns):
# 구        25 non-null object
# 인구수      25 non-null int64
# 남성       25 non-null int64
# 여성       25 non-null int64
# 내국인      25 non-null int64
# 남성내국인    25 non-null int64
# 여성내국인    25 non-null int64
# 외국인      25 non-null int64
# 남성외국인    25 non-null int64
# 여성외국인    25 non-null int64
# 세대당인구    25 non-null float64
# 고령자      25 non-null int64
# dtypes: float64(1), int64(10), object(1)
# memory usage: 3.2+ KB

# %%
raw_data.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>인구수</th>
#       <th>남성</th>
#       <th>여성</th>
#       <th>내국인</th>
#       <th>남성내국인</th>
#       <th>여성내국인</th>
#       <th>외국인</th>
#       <th>남성외국인</th>
#       <th>여성외국인</th>
#       <th>세대당인구</th>
#       <th>고령자</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>25.000000</td>
#       <td>25.000000</td>
#       <td>25.000000</td>
#       <td>25.00000</td>
#       <td>25.000000</td>
#       <td>25.000000</td>
#       <td>25.000000</td>
#       <td>25.000000</td>
#       <td>25.000000</td>
#       <td>25.00000</td>
#       <td>25.000000</td>
#     </tr>
#     <tr>
# ...

# %%
import numpy as np

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=['A', 'B', 'C', 'D'])
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>0.100800</td>
#       <td>1.479559</td>
#       <td>0.594920</td>
#       <td>-0.386255</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>-0.121609</td>
#       <td>0.314872</td>
#       <td>-0.726305</td>
#       <td>0.455966</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>-0.015332</td>
#       <td>-1.186633</td>
#       <td>0.928298</td>
#       <td>0.042061</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
# ...
