# %%
alist = ['a', 'b', 'c', 'd']
alist
# Out:
# ['a', 'b', 'c', 'd']

# %%
alist.extend(['e', 'f'])
alist
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-1-2100d0af3320> in <module>()
# ----> 1 alist.extend(['e', 'f'])
#       2 alist
#
# NameError: name 'alist' is not defined

# %%
alist.remove('e')
alist
# Out:
# ['a', 'b', 'c', 'd', 'f']

# %%
abc = alist[0:3]
abc
# Out:
# ['a', 'b', 'c']

# %%
alist
# Out:
# ['a', 'b', 'c', 'd', 'f']

# %%
alist.insert(1, 99)
alist
# Out:
# ['a', 99, 'b', 'c', 'd', 'f']

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
plt.figure()
plt.plot([1,2,3,4,5,6,7,8,9,8,7,6,5,4,3,2,1])
plt.show()

# %%
y = [1,2,3,4,5,6,7,8,9,8,7,6,5,4,3,2,1,0]
x = range(0,len(y))
plt.figure(figsize=(12,6))
plt.plot(x,y)
plt.grid()
plt.show()

# %%
t = np.arange(0,12,0.01)
y = np.sin(t)

plt.figure(figsize=(12,6))
plt.plot(t,y)
plt.grid()
plt.xlabel("time")
plt.ylabel("Amplitude")
plt.title('title')
plt.show()

# %%
t = np.arange(0,12,0.01)
y = np.sin(t)
yc = np.cos(t)
plt.figure(figsize=(12,6))
plt.plot(t,y,lw=5,label='sin')
plt.plot(t,yc,label='cos')
plt.grid()

plt.legend() #범례노출 
plt.xlabel("time")
plt.ylabel("Amplitude")
plt.title('title')
plt.show()

# %%
t = [0,1,2,3,4,5,6]
y = [1,4,5,8,9,3,5]
plt.figure(figsize=(10,6))
plt.plot(t,y,color='green')
plt.show()

# %%
t = [0,1,2,3,4,5,6]
y = [1,4,5,8,9,3,5]
plt.figure(figsize=(10,6))
plt.plot(t,y,color='green',linestyle='dashed',marker='o',markerfacecolor='red',markersize=12)
plt.show()

# %%
t = [0,1,2,3,4,5,6]
y = [1,4,5,8,9,3,5]
plt.figure(figsize=(10,6))
plt.scatter(t,y,s=50,c=t,marker='>')
plt.colorbar()
plt.grid()
plt.show()

# %%
import pandas as pd

# %%
# %pwd
# Out:
# '/Users/youngkwangkim/git/pythonExa-2018-1'

# %%
import matplotlib as mpl
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False
f_path = 'pythonExam2018-1/exam/font/malgun.ttf'
font_name = font_manager.FontProperties(fname=f_path).get_name()
print(font_name)
rc('font',family=font_name)
# Out:
# Malgun Gothic

# %%
print ('버전: ', mpl.__version__)
print ('설치 위치: ', mpl.__file__)
print ('설정 위치: ', mpl.get_configdir())
print ('캐시 위치: ', mpl.get_cachedir())
# Out:
# 버전:  2.2.2
# 설치 위치:  /Users/youngkwangkim/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py
# 설정 위치:  /Users/youngkwangkim/.matplotlib
# 캐시 위치:  /Users/youngkwangkim/.matplotlib

# %%
print ('설정파일 위치: ', mpl.matplotlib_fname())
# Out:
# 설정파일 위치:  /Users/youngkwangkim/anaconda3/lib/python3.6/site-packages/matplotlib/mpl-data/matplotlibrc

# %%
font_list_mac = font_manager.OSXInstalledFonts()
print(len(font_list_mac))
# Out:
# 176

# %%
font_list_mac[:10]
# Out:
# ['/Library/Fonts/Webdings.ttf',
#  '/Library/Fonts/Zapfino.ttf',
#  '/Library/Fonts/Trebuchet MS Italic.ttf',
#  '/Library/Fonts/Georgia.ttf',
#  '/Library/Fonts/Verdana Bold.ttf',
#  '/Library/Fonts/Bodoni 72 Smallcaps Book.ttf',
#  '/Library/Fonts/Times New Roman Bold Italic.ttf',
#  '/Library/Fonts/Silom.ttf',
#  '/Library/Fonts/Verdana Italic.ttf',
#  '/Library/Fonts/Times New Roman Italic.ttf']

# %%
f = [f.name for f in font_manager.fontManager.ttflist]
print(len(font_list_mac))
# 10개의 폰트명 만 출력
f[:10]
# Out:
# 176
# ['cmmi10',
#  'cmss10',
#  'DejaVu Sans',
#  'STIXSizeThreeSym',
#  'STIXNonUnicode',
#  'STIXSizeFourSym',
#  'STIXGeneral',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'DejaVu Sans']

# %%
[(f.name, f.fname) for f in font_manager.fontManager.ttflist if 'Nanum' in f.name]
# Out:
# [('NanumGothicCoding', '/Library/Fonts/나눔고딕코딩.ttf'),
#  ('NanumGothicCoding', '/Library/Fonts/나눔고딕코딩-Bold.ttf')]

# %%
print('serif 세리프가 있는 폰트--------')
print (plt.rcParams['font.serif']) 
print('sans-serif 세리프가 없는 폰트 --------')
print (plt.rcParams['font.sans-serif']) 
print('monospace 고정폭 글꼴--------')
print (plt.rcParams['font.monospace'])
# Out:
# serif 세리프가 있는 폰트--------
# ['DejaVu Serif', 'Bitstream Vera Serif', 'Computer Modern Roman', 'New Century Schoolbook', 'Century Schoolbook L', 'Utopia', 'ITC Bookman', 'Bookman', 'Nimbus Roman No9 L', 'Times New Roman', 'Times', 'Palatino', 'Charter', 'serif']
# sans-serif 세리프가 없는 폰트 --------
# ['DejaVu Sans', 'Bitstream Vera Sans', 'Computer Modern Sans Serif', 'Lucida Grande', 'Verdana', 'Geneva', 'Lucid', 'Arial', 'Helvetica', 'Avant Garde', 'sans-serif']
# monospace 고정폭 글꼴--------
# ['DejaVu Sans Mono', 'Bitstream Vera Sans Mono', 'Computer Modern Typewriter', 'Andale Mono', 'Nimbus Mono L', 'Courier New', 'Courier', 'Fixed', 'Terminal', 'monospace']

# %%
rc('font',family='NanumGothicCoding')

# %%
raw_data = pd.read_csv("pythonExam2018-1/exam/data/01. POP_result.csv",encoding='utf-8') 
raw_data
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>구</th>
#       <th>인구수</th>
#       <th>남성</th>
#       <th>여성</th>
#       <th>내국인</th>
#       <th>남성내국인</th>
#       <th>여성내국인</th>
#       <th>외국인</th>
#       <th>남성외국인</th>
#       <th>여성외국인</th>
#       <th>세대당인구</th>
#       <th>고령자</th>
#       <th>외국인비율</th>
#       <th>고령비율</th>
#       <th>여성비율</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>종로구</td>
#       <td>163569</td>
#       <td>79522</td>
#       <td>84047</td>
#       <td>153780</td>
#       <td>75247</td>
#       <td>78533</td>
#       <td>9789</td>
# ...

# %%
raw_data = pd.read_csv("pythonExam2018-1/exam/data/01. POP_result.csv",index_col=0,encoding='utf-8') 
raw_data
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>구</th>
#       <th>인구수</th>
#       <th>남성</th>
#       <th>여성</th>
#       <th>내국인</th>
#       <th>남성내국인</th>
#       <th>여성내국인</th>
#       <th>외국인</th>
#       <th>남성외국인</th>
#       <th>여성외국인</th>
#       <th>세대당인구</th>
#       <th>고령자</th>
#       <th>외국인비율</th>
#       <th>고령비율</th>
#       <th>여성비율</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>종로구</td>
#       <td>163569</td>
#       <td>79522</td>
#       <td>84047</td>
#       <td>153780</td>
#       <td>75247</td>
#       <td>78533</td>
#       <td>9789</td>
#       <td>4275</td>
#       <td>5514</td>
# ...

# %%
raw_data['인구수'].plot(kind='barh',grid=True,figsize=(10,10))

# %%
raw_data.set_index('구', inplace=True)
raw_data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>인구수</th>
#       <th>남성</th>
#       <th>여성</th>
#       <th>내국인</th>
#       <th>남성내국인</th>
#       <th>여성내국인</th>
#       <th>외국인</th>
#       <th>남성외국인</th>
#       <th>여성외국인</th>
#       <th>세대당인구</th>
#       <th>고령자</th>
#       <th>외국인비율</th>
#       <th>고령비율</th>
#       <th>여성비율</th>
#     </tr>
#     <tr>
#       <th>구</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
# ...

# %%
raw_data['인구수'].plot(kind='barh',grid=True,figsize=(10,10))

# %%
raw_data['고령자'].sort_values().plot(kind='barh',grid=True,figsize=(10,10))

# %%
raw_data['외국인비율'].sort_values().plot(kind='barh',grid=True,figsize=(10,10))

# %%
col = '인구수'
tmp_data = raw_data.sort_values(by=col, ascending=True)
plt.figure(figsize=(10,10))
plt.barh(tmp_data.index, tmp_data[col])
plt.xlabel(col)
plt.title('서울특별시')
plt.grid()
plt.show()

# %%
col = '고령자'
tmp_data = raw_data.sort_values(by=col, ascending=True)
plt.figure(figsize=(10,10))
plt.barh(tmp_data.index, tmp_data[col])
plt.xlabel(col)
plt.title('서울시 구별 ' +col          )
plt.grid()
plt.show()

# %%
col1 = '인구수'
col2 = '고령자'
tmp_data = raw_data.sort_values(by=col1, ascending=True)

plt.figure(figsize=(10,10))

plt.barh(tmp_data.index, tmp_data[col1], label=col1)
plt.barh(tmp_data.index, tmp_data[col2], label=col2)

plt.xlabel(col1)

plt.title('서울시 구별 ' +col1 + " , " +col2          )
plt.grid()
plt.show()

# %%
col1 = '인구수'
col2 = '외국인'
tmp_data = raw_data.sort_values(by=col1, ascending=True)

plt.figure(figsize=(10,10))

plt.barh(tmp_data.index, tmp_data[col1], label=col1)
plt.barh(tmp_data.index, tmp_data[col2], label=col2)

plt.xlabel(col1)

plt.title('서울시 구별 ' +col1 + " , " +col2          )
plt.grid()
plt.show()

# %%
raw_data.to_csv('pythonExam2018-1/exam/data/02.SEOUL_POP_data.csv',sep=',',encoding='utf-8')
