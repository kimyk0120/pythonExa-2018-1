# %% [markdown]
# # week5
#
# * 함수설정
# * Selenium 모듈을 이용한 크롤링

# %%
def test_def(a,b): # def(함수 선언), a,b를 입력 인자로 갖는 test_def 함수 선언
    return a+b # 인자를 입력하여 함수를 호출하면 a+b 결과 출력

# %%
test_def(10,5)
# Out:
# 15

# %%
def test_args(a, *arg): # a는 첫번째 인자, *args는 나머지. 여러개 인자 삽입 가능
    print("첫번째 인자: ", a)
    for each in arg:
        print("*arg 다른 인자", each)

# %%
test_args('a','b','c','d')
# Out:
# 첫번째 인자:  a
# *arg 다른 인자 b
# *arg 다른 인자 c
# *arg 다른 인자 d

# %%
def test_kwargs(**kwargs): # ** key-word : value형태로 인자 출력
    print(kwargs)

# %%
test_kwargs(A='aa',B='bb', C='cc')
# Out:
# {'C': 'cc', 'B': 'bb', 'A': 'aa'}

# %%
def test_kwargs(**kwargs):
    A = kwargs.get('A', 1) # key-word 'A'에 대한 value가 없을 때, 1 입력
    print(A)

# %%
test_kwargs()
# Out:
# 1

# %%
test_kwargs(A=10)
# Out:
# 10

# %%
# 함수표현을 연습하기 위한 그래프 그리기
import matplotlib.pyplot as plt # 기본 그래프 matplotlib 모듈 호출, plt 문자로 호출 
import numpy as np #숫자를 다루는 numpy모듈 호출
# %matplotlib inline

# %%
#sin그래프 그리기
# sin그래프 함수와 입력 인자들 선언
def plotSinwave(amp, freq, endTime, sampleTime, bias):
    """ 
    plot sine wave
    y = a sin(2 pi f t) + b
    """
# """ 함수 내용 """ 
    time = np.arange(0, endTime, sampleTime)
# time변수는 0~endTime까지, sampleTime 간격으로 생성
    result = amp*np.sin(2*np.pi*freq*time) + bias
# result변수는 sin함수 식   
    plt.figure(figsize =(12,6)) # 그래프 그리기, 보이는 크기는 '12,6'(가로세로비율)
    plt.plot(time, result); plt.grid(True) # x축 시간, y축 result로 하는 그래프, 눈금선
    plt.xlabel('time'); plt.ylabel('sin') # x, y축 제목
    plt.title(str(amp)+'*sin(2*pi*'+str(freq)+'*t)+'+str(bias)) # 그래프 제목
    plt.show() # 그래프 출력

# %%
plotSinwave(2,1,10,0.01,0) # 입력된 인자에 따른 함수 결과 출력

# %%
def plotSinwave(**kwargs):
    """
    plot sine wave
    y = a sin(2 pi f t) + b
    """
    
    endTime, sampleTime = kwargs.get('endTime',1), kwargs.get('sampleTime',0.01)
    amp, freq, bias = kwargs.get('amp',1), kwargs.get('freq',1), kwargs.get('bias',0)
    figsize = kwargs.get('figsize',(12,6))
    
    time = np.arange(0, endTime, sampleTime)
    result = amp*np.sin(2*np.pi*freq*time) + bias
    
        
    plt.figure(figsize =(12,6))
    plt.plot(time, result); plt.grid(True)
    plt.xlabel('time'); plt.ylabel('sin')
    plt.title(str(amp)+'*sin(2*pi*'+str(freq)+'*t)+'+str(bias))
    plt.show()

# %%
plotSinwave()

# %%
# %pwd
# Out:
# 'C:\\Users\\gusdu\\Documents\\FastCampus'

# %%
# Selenium 크롤링
from selenium import webdriver #모듈 불러오기
driver = webdriver.Chrome('../Fastcampus/driver/chromedriver') #웹 드라이버 경로 저장
driver.get('https://nid.naver.com/nidlogin.login') # 웹 드라이버를 이용하여 해당 url 화면 띄우기

# %%
elem_login = driver.find_element_by_id('id') # id 속성에 id속성값을 갖는 element 찾는 변수
elem_login.clear()                          # elem_login변수 id 입력창에 있는 내용 삭제
elem_login.send_keys('아이디 입력')
elem_login = driver.find_element_by_id('pw') # id 속성에 pw속성값을 갖는 element 찾는 변수
elem_login.clear()
elem_login.send_keys('비밀번호 입력')

# %%
xpath = """//*[@id="frmNIDLogin"]/fieldset/input""" # 로그인 버튼의 경로
driver.find_element_by_xpath(xpath).click() # 로그인 버턴을 클릭

# %%
driver.get("http://mail.naver.com") # 메일 페이지로 이동(get)

# %%
from bs4 import BeautifulSoup 

html = driver.page_source # 현재 화면에 보이는 페이지 html내용을 html변수에 저장
soup = BeautifulSoup(html, 'lxml') # 불러온 페이지 소스를 lxml형태로 구조 변형

# %%
list_ = soup.find_all('div','name _ccr(lst.from) ') 
# soup변수 내용 중 div태그 class value값이 다음과 같은 element 모두 찾아 저장
list_
# Out:
# [<div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|22794) _stopDefault" href="#" title='"이스타항공" &lt;newsletter@eastarjet.com&gt;'>이스타항공</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|22793) _stopDefault" href="#" title='"럭키위너" &lt;winner_1st@nate.com&gt;'>럭키위너</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|22792) _stopDefault" href="#" title='"현대Hmall" &lt;customer@hyundaihmall.com&gt;'>현대Hmall</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|22791) _stopDefault" href="#" title='"DBGuide" &lt;newsletter@dbguide.net&gt;'>DBGuide</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|22790) _stopDefault" href="#" title='"중고나라" &lt;navercafe@naver.com&gt;'>중고나라</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|22789) _stopDefault" href="#" title='"증산정보도서관" &lt;master@jsplib.or.kr&gt;'>증산정보도서관</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|22788) _stopDefault" href="#" title='"류지혁" &lt;xolichouse@naver.com&gt;'>류지혁</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|22787) _stopDefault" href="#" title='"네이버페이" &lt;naverpayadmin_noreply@naver.com&gt;'>네이버페이</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|22786) _stopDefault" href="#" title='"KB국민은행" &lt;kbmail@kbmail.kbstar.com&gt;'>KB국민은행</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|22785) _stopDefault" href="#" title='"증산정보도서관" &lt;master@jsplib.or.kr&gt;'>증산정보도서관</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|22784) _stopDefault" href="#" title='"DBGuide" &lt;newsletter@dbguide.net&gt;'>DBGuide</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|22783) _stopDefault" href="#" title='"네이버페이" &lt;naverpayadmin_noreply@naver.com&gt;'>네이버페이</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|22782) _stopDefault" href="#" title='"로또당첨예상번호" &lt;maxbounty.kr@gmail.com&gt;'>로또당첨예상번호</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|22781) _stopDefault" href="#" title='"럭키위너" &lt;winner_1st@nate.com&gt;'>럭키위너</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|22780) _stopDefault" href="#" title='"KB이사" &lt;vhwkd@nate.com&gt;'>KB이사</a></div>]

# %%
list_n = [each.a.string for each in list_] 
# insex순서를 갖는 list형태의 list_를 하나씩 each에 반영하여 a태그의 문자열을 저장
list_n
# Out:
# ['이스타항공',
#  '럭키위너',
#  '현대Hmall',
#  'DBGuide',
#  '중고나라',
#  '증산정보도서관',
#  '류지혁',
#  '네이버페이',
#  'KB국민은행',
#  '증산정보도서관',
#  'DBGuide',
#  '네이버페이',
#  '로또당첨예상번호',
#  '럭키위너',
#  'KB이사']

# %%
driver.close() # 브라우저 창 닫기

# %%
#서울 구별 주유정보 가져오기

from selenium import webdriver
driver = webdriver.Chrome('../Fastcampus/driver/chromedriver') # chromedriver 경로
driver.get("http://www.opinet.co.kr/searRgSelect.do") # url이동

# %%
sido_list_raw = driver.find_element_by_id('SIDO_NM0') 
# 웹페이지에서 id 속성의 value값이 'SIDO_NM0'인 element찾아 저장
sido_list_raw
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="1fe8326e66c09525e8fdd9e4712eeabb", element="0.635233709175224-1")>

# %%
sido_list = sido_list_raw.find_element_by_tag_name("option")
# sido_list_raw 변수 중 option 태그 element 찾기
sido_list
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="1fe8326e66c09525e8fdd9e4712eeabb", element="0.635233709175224-2")>

# %%
# 각 시도 명칭은 id : SIDO_NM0 > option > attribute 속성값
# sido_list_raw 변수값 중 option태그를 모두 찾고 속성값을 저장
sido_name = [option.get_attribute("value") 
            for option in sido_list_raw.find_elements_by_tag_name("option")]
print(sido_name)
sido_name.remove('') # 첫번째 결과값에서 '' 내용 제거
sido_name
# Out:
# ['', '서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시', '울산광역시', '세종특별자치시', '경기도', '강원도', '충청북도', '충청남도', '전라북도', '전라남도', '경상북도', '경상남도', '제주특별자치도']
# ['서울특별시',
#  '부산광역시',
#  '대구광역시',
#  '인천광역시',
#  '광주광역시',
#  '대전광역시',
#  '울산광역시',
#  '세종특별자치시',
#  '경기도',
#  '강원도',
#  '충청북도',
#  '충청남도',
#  '전라북도',
#  '전라남도',
#  '경상북도',
#  '경상남도',
#  '제주특별자치도']

# %%
sido_list_raw.send_keys(sido_name[0]) # sido_name변수값 중 첫번째, '서울특별시' 입력

# %%
gu_list_raw = driver.find_element_by_id("SIGUNGU_NM0")
# id속성 값이 SIGUNGU_NM0인 elements 찾아 저장
gu_names = [option.get_attribute('value')
           for option in gu_list_raw.find_elements_by_tag_name("option")]
# 구 이름 가져오기
print(gu_names)
gu_names.remove("")
gu_names
# Out:
# ['', '강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구']
# ['강남구',
#  '강동구',
#  '강북구',
#  '강서구',
#  '관악구',
#  '광진구',
#  '구로구',
#  '금천구',
#  '노원구',
#  '도봉구',
#  '동대문구',
#  '동작구',
#  '마포구',
#  '서대문구',
#  '서초구',
#  '성동구',
#  '성북구',
#  '송파구',
#  '양천구',
#  '영등포구',
#  '용산구',
#  '은평구',
#  '종로구',
#  '중구',
#  '중랑구']

# %%
gu_list_raw.send_keys(gu_names[0]) # gu_name의 첫번쨰 값 입력

# %%
element_get_excel = driver.find_element_by_id('glopopd_excel').click()
# excel 첨부파일 클릭

# %%
#각 구별 첨부파일 가져오기
import time
for gu in gu_names:
    element = driver.find_element_by_id("SIGUNGU_NM0")
    element.send_keys(gu) # gu_names 변수값 순서대로 입력
    time.sleep(2)
    
    element_get_excel = driver.find_element_by_id("glopopd_excel").click() # 첨부파일 클릭
    time.sleep(2)

# %%
driver.close()

# %%
import pandas as pd
from glob import glob # 파일이름을 특수문자로 다루도록 하는 모듈
glob('../Fastcampus/data/*.xls') # 다음과 같은 경로에 .xls파일 list형태로 출력
# Out:
# ['../Fastcampus/data\\01_OctagonExcel_seoul.xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (1).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (10).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (11).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (12).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (13).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (14).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (15).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (16).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (17).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (18).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (19).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (2).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (20).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (21).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (22).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (23).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (24).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (3).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (4).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (5).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (6).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (7).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (8).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (9).xls',
#  '../Fastcampus/data\\지역_위치별(주유소).xls']

# %%
station_files = glob('../Fastcampus/data/지역_*.xls') 
# glob 모듈에 해당하는 파일 list 형태로 저장
station_files
# Out:
# ['../Fastcampus/data\\지역_위치별(주유소) (1).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (10).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (11).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (12).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (13).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (14).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (15).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (16).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (17).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (18).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (19).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (2).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (20).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (21).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (22).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (23).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (24).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (3).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (4).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (5).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (6).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (7).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (8).xls',
#  '../Fastcampus/data\\지역_위치별(주유소) (9).xls',
#  '../Fastcampus/data\\지역_위치별(주유소).xls']

# %%
pd.read_excel(station_files[0])
# Out:
#    지역_위치별(주유소)           Unnamed: 1                  Unnamed: 2 Unnamed: 3  \
# 0          NaN                  NaN                         NaN        NaN
# 1           지역                   상호                          주소         상표
# 2        서울특별시               구천면주유소       서울 강동구 구천면로 357 (암사동)     현대오일뱅크
# 3        서울특별시       GS칼텍스㈜직영 신월주유소      서울 강동구 양재대로 1323 (성내동)      GS칼텍스
# 4        서울특별시     주)지유에너지직영 오렌지주유소    서울특별시 강동구  성안로 102 (성내동)      SK에너지
# 5        서울특별시                광성주유소       서울 강동구 올림픽로 673 (천호동)      S-OIL
# 6        서울특별시       대성석유(주)직영길동주유소      서울 강동구 천호대로 1168 (둔촌동)      GS칼텍스
# 7        서울특별시              고속셀프주유소  서울특별시 강동구  천호대로 1246 (둔촌동)      SK에너지
# 8        서울특별시              방아다리주유소        서울 강동구 동남로 811 (명일동)      SK에너지
# 9        서울특별시   SK네트웍스㈜암사주유소(self)       서울 강동구 올림픽로 749 (암사동)      SK에너지
# 10       서울특별시         알이디씨(주)천동주유소   서울특별시 강동구  천호대로 987 (천호동)     현대오일뱅크
# 11       서울특별시             sk해뜨는주유소    서울특별시 강동구  상일로 132 (강일동)      SK에너지
# 12       서울특별시      (주)퍼스트오일 코알라주유소   서울특별시 강동구  올림픽로 556 (성내동)      S-OIL
# 13       서울특별시  (주)소모에너지엔테크놀러지성내주유소       서울 강동구 올림픽로 578 (성내동)      GS칼텍스
# 14       서울특별시       (주)삼표에너지 고덕주유소         서울 강동구 고덕로 39 (암사동)      GS칼텍스
# 15       서울특별시       SK네트윅스(주)길동주유소       서울 강동구 천호대로 1221 (길동)      SK에너지
# 16       서울특별시   CJ대한통운(주)직영 천호점주유소         서울 강동구 천중로 67 (천호동)     현대오일뱅크
# 17       서울특별시                명일주유소        서울 강동구 고덕로 168 (명일동)      SK에너지
# 18       서울특별시                강동주유소       서울 강동구 양재대로 1509 (길동)      SK에너지
# 19       서울특별시        명진석유(주)동서울주유소  서울특별시 강동구  천호대로 1456 (상일동)      GS칼텍스
#
#       Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8   Unnamed: 9
# 0            NaN        NaN        NaN        NaN        NaN  (단위 : 원/리터)
# 1           전화번호       셀프여부      고급휘발유        휘발유         경유         실내등유
# 2    02-441-0536          N          -       1627       1425            -
# 3    02-475-2600          N       1898       1629       1439         1050
# 4    02-484-6165          N          -       1638       1448         1047
# 5    02-470-5133          N          -       1658       1458         1100
# 6    02-474-7222          N       1917       1658       1468         1100
# 7    02-487-2030          Y       1858       1658       1468            -
# 8    02-442-5145          Y          -       1658       1468          990
# 9   02-3427-2043          Y       1854       1668       1468            -
# 10   02-473-1556          N          -       1668       1468            -
# 11   02-442-7801          Y          -       1668       1488         1000
# 12   02-484-1162          Y          -       1668       1468            -
# 13   02-479-3838          Y          -       1678       1478            -
# 14   02-441-3327          N       1919       1719       1519         1180
# 15   02-488-3491          Y       1901       1748       1548            -
# 16   02-473-5189          N          -       1767       1579         1100
# 17  02-3428-1739          N       1909       1769       1594            -
# 18   02-477-5101          N       2363       2093       1888         1388
# 19   02-427-5230          Y          -          -          -            -

# %%
pd.read_excel(station_files[0], header = 2) # list 첫번째 excel파일 불러와 내용의 상위 두줄 삭제
# Out:
#        지역                   상호                          주소      상표  \
# 0   서울특별시               구천면주유소       서울 강동구 구천면로 357 (암사동)  현대오일뱅크
# 1   서울특별시       GS칼텍스㈜직영 신월주유소      서울 강동구 양재대로 1323 (성내동)   GS칼텍스
# 2   서울특별시     주)지유에너지직영 오렌지주유소    서울특별시 강동구  성안로 102 (성내동)   SK에너지
# 3   서울특별시                광성주유소       서울 강동구 올림픽로 673 (천호동)   S-OIL
# 4   서울특별시       대성석유(주)직영길동주유소      서울 강동구 천호대로 1168 (둔촌동)   GS칼텍스
# 5   서울특별시              고속셀프주유소  서울특별시 강동구  천호대로 1246 (둔촌동)   SK에너지
# 6   서울특별시              방아다리주유소        서울 강동구 동남로 811 (명일동)   SK에너지
# 7   서울특별시   SK네트웍스㈜암사주유소(self)       서울 강동구 올림픽로 749 (암사동)   SK에너지
# 8   서울특별시         알이디씨(주)천동주유소   서울특별시 강동구  천호대로 987 (천호동)  현대오일뱅크
# 9   서울특별시             sk해뜨는주유소    서울특별시 강동구  상일로 132 (강일동)   SK에너지
# 10  서울특별시      (주)퍼스트오일 코알라주유소   서울특별시 강동구  올림픽로 556 (성내동)   S-OIL
# 11  서울특별시  (주)소모에너지엔테크놀러지성내주유소       서울 강동구 올림픽로 578 (성내동)   GS칼텍스
# 12  서울특별시       (주)삼표에너지 고덕주유소         서울 강동구 고덕로 39 (암사동)   GS칼텍스
# 13  서울특별시       SK네트윅스(주)길동주유소       서울 강동구 천호대로 1221 (길동)   SK에너지
# 14  서울특별시   CJ대한통운(주)직영 천호점주유소         서울 강동구 천중로 67 (천호동)  현대오일뱅크
# 15  서울특별시                명일주유소        서울 강동구 고덕로 168 (명일동)   SK에너지
# 16  서울특별시                강동주유소       서울 강동구 양재대로 1509 (길동)   SK에너지
# 17  서울특별시        명진석유(주)동서울주유소  서울특별시 강동구  천호대로 1456 (상일동)   GS칼텍스
#
#             전화번호 셀프여부 고급휘발유   휘발유    경유  실내등유
# 0    02-441-0536    N     -  1627  1425     -
# 1    02-475-2600    N  1898  1629  1439  1050
# 2    02-484-6165    N     -  1638  1448  1047
# 3    02-470-5133    N     -  1658  1458  1100
# 4    02-474-7222    N  1917  1658  1468  1100
# 5    02-487-2030    Y  1858  1658  1468     -
# 6    02-442-5145    Y     -  1658  1468   990
# 7   02-3427-2043    Y  1854  1668  1468     -
# 8    02-473-1556    N     -  1668  1468     -
# 9    02-442-7801    Y     -  1668  1488  1000
# 10   02-484-1162    Y     -  1668  1468     -
# 11   02-479-3838    Y     -  1678  1478     -
# 12   02-441-3327    N  1919  1719  1519  1180
# 13   02-488-3491    Y  1901  1748  1548     -
# 14   02-473-5189    N     -  1767  1579  1100
# 15  02-3428-1739    N  1909  1769  1594     -
# 16   02-477-5101    N  2363  2093  1888  1388
# 17   02-427-5230    Y     -     -     -     -

# %%
tmp_raw = []

for file_name in station_files:
    tmp = pd.read_excel(file_name, header = 2)
    tmp_raw.append(tmp) # 동일한 구조의 파일이라서 내용을 모두 한 list에 저장  
print(tmp_raw)
station_raw = pd.concat(tmp_raw) #concat : 각 list 내용을 하나의 파일로 변환
# Out:
# [       지역                   상호                          주소      상표  \
# 0   서울특별시               구천면주유소       서울 강동구 구천면로 357 (암사동)  현대오일뱅크
# 1   서울특별시       GS칼텍스㈜직영 신월주유소      서울 강동구 양재대로 1323 (성내동)   GS칼텍스
# 2   서울특별시     주)지유에너지직영 오렌지주유소    서울특별시 강동구  성안로 102 (성내동)   SK에너지
# 3   서울특별시                광성주유소       서울 강동구 올림픽로 673 (천호동)   S-OIL
# 4   서울특별시       대성석유(주)직영길동주유소      서울 강동구 천호대로 1168 (둔촌동)   GS칼텍스
# 5   서울특별시              고속셀프주유소  서울특별시 강동구  천호대로 1246 (둔촌동)   SK에너지
# 6   서울특별시              방아다리주유소        서울 강동구 동남로 811 (명일동)   SK에너지
# 7   서울특별시   SK네트웍스㈜암사주유소(self)       서울 강동구 올림픽로 749 (암사동)   SK에너지
# 8   서울특별시         알이디씨(주)천동주유소   서울특별시 강동구  천호대로 987 (천호동)  현대오일뱅크
# 9   서울특별시             sk해뜨는주유소    서울특별시 강동구  상일로 132 (강일동)   SK에너지
# 10  서울특별시      (주)퍼스트오일 코알라주유소   서울특별시 강동구  올림픽로 556 (성내동)   S-OIL
# 11  서울특별시  (주)소모에너지엔테크놀러지성내주유소       서울 강동구 올림픽로 578 (성내동)   GS칼텍스
# 12  서울특별시       (주)삼표에너지 고덕주유소         서울 강동구 고덕로 39 (암사동)   GS칼텍스
# 13  서울특별시       SK네트윅스(주)길동주유소       서울 강동구 천호대로 1221 (길동)   SK에너지
# 14  서울특별시   CJ대한통운(주)직영 천호점주유소         서울 강동구 천중로 67 (천호동)  현대오일뱅크
# 15  서울특별시                명일주유소        서울 강동구 고덕로 168 (명일동)   SK에너지
# 16  서울특별시                강동주유소       서울 강동구 양재대로 1509 (길동)   SK에너지
# 17  서울특별시        명진석유(주)동서울주유소  서울특별시 강동구  천호대로 1456 (상일동)   GS칼텍스
#
#             전화번호 셀프여부 고급휘발유   휘발유    경유  실내등유
# 0    02-441-0536    N     -  1627  1425     -
# 1    02-475-2600    N  1898  1629  1439  1050
# 2    02-484-6165    N     -  1638  1448  1047
# 3    02-470-5133    N     -  1658  1458  1100
# 4    02-474-7222    N  1917  1658  1468  1100
# 5    02-487-2030    Y  1858  1658  1468     -
# 6    02-442-5145    Y     -  1658  1468   990
# 7   02-3427-2043    Y  1854  1668  1468     -
# 8    02-473-1556    N     -  1668  1468     -
# 9    02-442-7801    Y     -  1668  1488  1000
# 10   02-484-1162    Y     -  1668  1468     -
# 11   02-479-3838    Y     -  1678  1478     -
# 12   02-441-3327    N  1919  1719  1519  1180
# 13   02-488-3491    Y  1901  1748  1548     -
# 14   02-473-5189    N     -  1767  1579  1100
# 15  02-3428-1739    N  1909  1769  1594     -
# 16   02-477-5101    N  2363  2093  1888  1388
# 17   02-427-5230    Y     -     -     -     -  ,        지역               상호                          주소      상표           전화번호  \
# 16    N     -  1669  1469     -
# 17    N     -  1699  1455     -
# 18    N     -  1762  1555  1100
# 19    N  1938  1798  1568     -
# 20    N     -  1845  1645     -
# 21    N     -  1977  1765     -  ,        지역                   상호                         주소      상표  \
# 0   서울특별시                서경주유소       서울 동작구 대림로 46 (신대방동)  현대오일뱅크
# 1   서울특별시              21세기주유소     서울 동작구 시흥대로 616 (신대방동)   SK에너지
# 2   서울특별시                금성주유소    서울특별시 동작구  사당로 59 (상도동)  현대오일뱅크
# 3   서울특별시                대방주유소   서울특별시 동작구 여의대방로214 (대방동)   GS칼텍스
# 4   서울특별시             한원케미칼(주)  서울특별시 동작구  동작대로 135 (사당동)   GS칼텍스
# 5   서울특별시  현대오일뱅크(주)직영 사당셀프주유소   서울특별시 동작구  동작대로 73 (사당동)  현대오일뱅크
# 6   서울특별시                매일주유소   서울특별시 동작구  상도로 139 (상도동)   S-OIL
# 7   서울특별시                  흑석동       서울 동작구 현충로 101 (흑석동)   SK에너지
# 8   서울특별시       대성산업(주) 노량진주유소     서울 동작구 노량진로 172 (노량진동)   GS칼텍스
# 9   서울특별시         현대오일뱅크 동작주유소   서울특별시 동작구  상도로 403 (상도동)  현대오일뱅크
# 10  서울특별시               살피재주유소   서울특별시 동작구  상도로 334 (상도동)   SK에너지
#
#             전화번호 셀프여부 고급휘발유   휘발유    경유  실내등유
# 0    02-843-5130    N     -  1596  1396     -
# 1    02-832-7926    Y  1967  1599  1409     -
# 2    02-825-5151    N     -  1618  1428     -
# 3    02-826-5145    N  1809  1618  1418  1000
# 4   02-2183-3824    Y     -  1618  1428     -
# 5    02-521-3618    Y     -  1628  1438     -
# 6    02-817-4085    N     -  1629  1429  1000
# 7    02-815-0724    Y     -  1639  1459     -
# 8    02-815-2354    N     -  1657  1477   929
# 9    02-817-9179    N     -  1679  1469  1100
# 10   02-817-2559    N     -  1685  1475     -  ,        지역            상호                        주소      상표           전화번호 셀프여부  \
# 0   서울특별시       마포시엠주유소  서울특별시 마포구  월드컵북로62 (성산동)   GS칼텍스    02-336-1687    N
# 1   서울특별시         용강주유소  서울특별시 마포구  토정로 260 (용강동)   S-OIL  070-7795-4800    N
# 2   서울특별시   (주)만성상사(대흥)       서울 마포구 대흥로 61 (대흥동)   SK에너지   02-3273-5151    N
# 3   서울특별시  (주)승지 염리동주유소    서울특별시 마포구 백범로 126(염리동)  현대오일뱅크    02-716-3644    N
# 4   서울특별시         청원주유소    서울 마포구 월드컵북로 113 (성산동)   S-OIL    02-325-5533    N
# 5   서울특별시         성산주유소    서울 마포구 월드컵북로 170 (성산동)   SK에너지    02-373-3314    N
# 6   서울특별시        망원동주유소     서울 마포구 월드컵로 119 (망원동)   SK에너지    02-334-0917    N
# 7   서울특별시         안국주유소       서울 마포구 양화로 33 (합정동)   SK에너지    02-334-8030    N
# 8   서울특별시         마포주유소     서울 마포구 마포대로 186 (공덕동)   S-OIL    02-701-3990    N
# 9   서울특별시   SK에너지 양지주유소      서울 마포구 마포대로 69 (도화동)   SK에너지    02-706-8955    N
# 38   02-581-5101    N  2378  2117  1947     -
# 39  02-3481-2513    N  2274  2134  1944     -
# 40   02-577-1621    N  2417  2276  2069     -  ,        지역                상호                           주소      상표  \
# 0   서울특별시       (주)서울에너지 직영        서울 성동구 천호대로 324 (용답동)   S-OIL
# 1   서울특별시             정호주유소        서울 성동구 고산자로 307 (마장동)    자가상표
# 2   서울특별시     태은에너지KLP제2주유소      서울특별시 성동구 동일로 249 (송정동)  현대오일뱅크
# 3   서울특별시            도루코주유소      서울 성동구 아차산로 180 (성수동2가)   GS칼텍스
# 4   서울특별시            아이콘주유소     서울특별시 성동구 고산자로 273 (도선동)   S-OIL
# 5   서울특별시             경진주유소        서울 성동구 고산자로 348 (마장동)   SK에너지
# 6   서울특별시  현대오일뱅크(주)성동현대주유소     서울특별시 성동구  마장로 311 (마장동)  현대오일뱅크
# 7   서울특별시             삼우주유소        서울 성동구 천호대로 392 (용답동)   SK에너지
# 8   서울특별시   SK에너지(주) 군자동주유소        서울 성동구 천호대로 446 (용답동)   SK에너지
# 9   서울특별시   kh에너지(주)성수만세주유소   서울특별시 성동구 왕십리로 109 (성수동1가)   SK에너지
# 10  서울특별시       현대오일뱅크성수주유소       서울 성동구 뚝섬로 352 (성수동1가)  현대오일뱅크
# 11  서울특별시          SK세원2주유소      서울 성동구 광나루로 184 (성수동1가)   SK에너지
# 12  서울특별시             동부주유소  서울특별시 성동구  광나루로 146 (성수동1가)   GS칼텍스
# 13  서울특별시    SK네트웍스(주)효진주유소  1 서울특별시 성동구 동일로 129 (성수동2가)   SK에너지
# 14  서울특별시             금호주유소        서울 성동구 금호로 39 (금호동4가)   GS칼텍스
# 15  서울특별시             동일주유소      서울 성동구 광나루로 254 (성수동2가)  현대오일뱅크
# 16  서울특별시            청계로주유소      서울 성동구 청계천로 454 (하왕십리동)   SK에너지
# 17  서울특별시     (주)옥수하이웨이스테이션        서울 성동구 독서당로 168 (옥수동)   GS칼텍스
#
#             전화번호 셀프여부 고급휘발유   휘발유    경유  실내등유
# 0   02-3390-4338    Y     -  1589  1398     -
# 1   02-2297-9442    N     -  1608  1398  1050
# 2    02-465-5182    Y     -  1613  1408     -
# 3    02-463-6919    Y  1829  1613  1419  1150
# 4   02-2291-5189    N     -  1648  1428     -
# 5   02-2295-3331    N     -  1658  1448  1200
# 6   02-2299-7333    N     -  1659  1438  1200
# 7   02-2245-8974    N     -  1669  1565     -
# 8   02-2244-4945    N  1876  1677  1479     -
# 9    02-499-8223    Y  1905  1683  1483     -
# 10   02-467-7240    N     -  1685  1484  1150
# 11   02-462-5665    N  2050  1750  1560     -
# 12   02-462-3566    N     -  1768  1557  1150
# 13   02-464-7252    N  1919  1769  1569  1211
# 14  02-2297-0066    N     -  1795  1596  1260
# 15   02-461-7100    N  2073  1835  1634  1149
# 16  02-2294-4225    N     -  1898  1697  1095
# 17  02-2282-5151    N  2199  1940  1785     -  ,        지역                   상호                           주소      상표  \
# 0   서울특별시                원천주유소    서울특별시 성북구  돌곶이로 142 (장위동)   알뜰주유소
# 6   서울특별시                (주)블루에너지                서울특별시 영등포구  가마산로 367 (대림동)
# 7   서울특별시                   매봉주유소                     서울 영등포구 도신로 248 (신길동)
# 8   서울특별시                   신길주유소                   서울특별시 영등포구 신길로 74 (신길동)
# 9   서울특별시                   행촌주유소                     서울 영등포구 도신로 130 (신길동)
# 10  서울특별시                  선유도주유소                   서울 영등포구 양평로 141 (양평동5가)
# 11  서울특별시         (주)한미석유 제2한강주유소                   서울 영등포구 선유로 260 (양평동4가)
# 12  서울특별시  SK네트웍스(주) 영등포행복SELF주유소                 서울특별시 영등포구 선유로 114(양평동1가)
# 13  서울특별시            한경석유(주)경덕주유소                  서울 영등포구 여의대방로23길 2 (신길동)
# 14  서울특별시                   보라주유소                서울특별시 영등포구  영등포로 399 (신길동)
# 15  서울특별시          SK에너지(주) 양평주유소                   서울 영등포구 선유로 195 (양평동3가)
# 16  서울특별시                 남부(영등포)                    서울 영등포구 경인로 822 (영등포동)
# 17  서울특별시            씨앤에스유통 한성주유소               서울특별시 영등포구  여의대방로 227 (신길동)
# 18  서울특별시                  모드니주유소                   서울 영등포구 경인로 789 (문래동3가)
# 19  서울특별시        SK네트웍스(주)직영기린주유소                   서울 영등포구 선유로 270 (양평동4가)
# 20  서울특별시                   화일주유소               서울특별시 영등포구  도림로 415 (문래동2가)
# 21  서울특별시                   대일주유소                  서울 영등포구 영등포로 168 (당산동1가)
# 22  서울특별시         SK에너지(주) 신길동주유소                    서울 영등포구 영등포로 348 (신길동)
# 23  서울특별시                   대영주유소                 서울 영등포구 국회대로 632 (영등포동7가)
# 24  서울특별시              선익개발영등포주유소                서울 영등포구 경인로114길 2 (영등포동1가)
# 25  서울특별시                 sk여명주유소              서울특별시 영등포구  국회대로62길 7 (여의도동)
# 26  서울특별시                   한일주유소                   서울 영등포구 도림로 486 (문래동3가)
# 27  서울특별시          성원이앤에스(주)영등포지점         서울특별시 영등포구  국회대로52길 9-13 (영등포동7가)
# 28  서울특별시                버드나룻길주유소                   서울 영등포구 버드나루로 111 (당산동)
# 29  서울특별시                KH여의도주유소                   서울 영등포구 국회대로 794 (여의도동)
# 30  서울특별시                 국회대로주유소               서울특별시 영등포구  국회대로 746 (여의도동)
# 31  서울특별시          SJ오일(주) 여의도주유소  서울특별시 영등포구  은행로 64 (여의도동) SJ오일(주) 여의도주유소
# 32  서울특별시          SK네트웍스직영여의도주유소                  서울 영등포구 의사당대로 154 (여의도동)
# 33  서울특별시                   하나주유소                 서울특별시 영등포구  도림로 236 (신길동)
#
#         상표           전화번호 셀프여부 고급휘발유   휘발유    경유  실내등유
# 0    SK에너지    02-847-5151    Y     -  1596  1396     -
# 1    GS칼텍스    02-841-8780    N     -  1596  1396     -
# 2    알뜰주유소    02-835-8881    Y     -  1596  1396     -
# 3   현대오일뱅크    02-849-5577    N     -  1596  1396     -
# 4    S-OIL    02-842-6148    Y     -  1596  1396     -
# 5   현대오일뱅크    02-832-1700    N     -  1596  1396   879
# 6    SK에너지    02-843-5151    Y     -  1596  1396     -
# 7   현대오일뱅크    02-836-8851    N     -  1608  1415     -
# 6   서울특별시            범아주유소(주)        서울 중랑구 동일로 881 (묵동)   S-OIL
# 7   서울특별시         망우주유소(self)       서울 중랑구 망우로 311 (상봉동)   GS칼텍스
# 8   서울특별시           구도일주유소 동천   서울특별시 중랑구  동일로 654 (면목동)   S-OIL
# 9   서울특별시      현대오일뱅크(주)대창주유소       서울 중랑구 동일로 636 (면목동)  현대오일뱅크
# 10  서울특별시               소망주유소   서울특별시 중랑구  망우로 475 (망우동)   GS칼텍스
# 11  서울특별시               면목주유소       서울 중랑구 동일로 627 (면목동)   S-OIL
# 12  서울특별시               신내주유소      서울 중랑구 용마산로 705 (신내동)   SK에너지
# 13  서울특별시            (주)기지에너지      서울 중랑구 용마산로 716 (신내동)   S-OIL
# 14  서울특별시              구도일주유소       서울 중랑구 망우로 170 (상봉동)   S-OIL
# 15  서울특별시                 중랑교       서울 중랑구 망우로 229 (중화동)   SK에너지
# 16  서울특별시  SK네트웍스(주)SELF상봉주유소  서울특별시 중랑구  망우로62길 8 (망우동)   SK에너지
# 17  서울특별시         유성주유소(self)       서울 중랑구 망우로 436 (망우동)  현대오일뱅크
#
#              전화번호 셀프여부 고급휘발유   휘발유    경유  실내등유
# 0   070-7797-7474    N     -  1597  1399     -
# 1     02-436-3651    Y     -  1598  1399  1100
# 2     02-433-9990    N     -  1605  1415     -
# 3     02-437-5457    N     -  1605  1415  1000
# 4     02-438-6111    Y  1755  1605  1407     -
# 5     02-439-3039    Y     -  1609  1409  1000
# 6     02-974-8356    N     -  1615  1415  1090
# 7     02-432-5145    Y     -  1615  1417     -
# 8     02-495-0081    N     -  1619  1419     -
# 9     02-432-9200    N     -  1619  1419  1000
# 10    02-494-0400    Y     -  1627  1429     -
# 11    02-437-4072    N     -  1628  1428     -
# 12   02-2207-0523    Y     -  1628  1429  1000
# 13   02-2207-9419    N     -  1629  1429  1000
# 14    02-438-5151    N     -  1638  1438  1100
# 15    02-493-0115    Y  1939  1639  1439     -
# 16   02-2208-2546    Y     -  1639  1439     -
# 17    02-496-3000    Y     -     -     -     -  ,        지역                 상호                               주소      상표  \
# 0   서울특별시          강서오곡셀프주유소          서울특별시 강서구 벌말로 254 (오곡동)   SK에너지
# 1   서울특별시              목화주유소        서울특별시 강서구  국회대로 251 (화곡동)   SK에너지
# 2   서울특별시              방화주유소           서울 강서구 방화동로 58-2 (방화동)   SK에너지
# 3   서울특별시             뉴신정주유소       서울특별시 강서구 곰달래로39길 10 (화곡동)   알뜰주유소
# 4   서울특별시        행촌에너지 공항주유소        서울특별시 강서구  개화동로 420 (개화동)  현대오일뱅크
# 5   서울특별시       현대오일뱅크 등촌주유소          서울특별시 강서구 등촌로 189 (등촌동)  현대오일뱅크
# 6   서울특별시              유턴주유소               서울특별시 강서구 남부순환로 57   알뜰주유소
# 7   서울특별시             화곡역주유소         서울특별시 강서구  강서로 154 (화곡동)   알뜰주유소
# 8   서울특별시            경인고속주유소         서울특별시 강서구 국회대로 225 (화곡동)   GS칼텍스
# 9   서울특별시        ㈜한진 김포공항주유소          서울특별시 강서구 하늘길 259(외발산동)   S-OIL
# %%
station_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 523 entries, 0 to 41
# Data columns (total 10 columns):
# 지역       523 non-null object
# 상호       523 non-null object
# 주소       523 non-null object
# 상표       523 non-null object
# 전화번호     523 non-null object
# 셀프여부     523 non-null object
# 고급휘발유    523 non-null object
# 휘발유      523 non-null object
# 경유       523 non-null object
# 실내등유     523 non-null object
# dtypes: object(10)
# memory usage: 44.9+ KB

# %%
station_raw.head()
# Out:
#       지역                상호                        주소      상표         전화번호  \
# 0  서울특별시            구천면주유소     서울 강동구 구천면로 357 (암사동)  현대오일뱅크  02-441-0536
# 1  서울특별시    GS칼텍스㈜직영 신월주유소    서울 강동구 양재대로 1323 (성내동)   GS칼텍스  02-475-2600
# 2  서울특별시  주)지유에너지직영 오렌지주유소  서울특별시 강동구  성안로 102 (성내동)   SK에너지  02-484-6165
# 3  서울특별시             광성주유소     서울 강동구 올림픽로 673 (천호동)   S-OIL  02-470-5133
# 4  서울특별시    대성석유(주)직영길동주유소    서울 강동구 천호대로 1168 (둔촌동)   GS칼텍스  02-474-7222
#
#   셀프여부 고급휘발유   휘발유    경유  실내등유
# 0    N     -  1627  1425     -
# 1    N  1898  1629  1439  1050
# 2    N     -  1638  1448  1047
# 3    N     -  1658  1458  1100
# 4    N  1917  1658  1468  1100

# %%
# station_raw data 중 상호, 주소, 휘발유, 셀프여부, 상표 정보만 dataframe구성
stations = pd.DataFrame({'상호':station_raw['상호'],
                        '주소':station_raw['주소'],
                        '가격':station_raw['휘발유'],
                        '셀프':station_raw['셀프여부'],
                        '상표':station_raw['상표'] })
stations.head()
# Out:
#      가격      상표                상호 셀프                        주소
# 0  1627  현대오일뱅크            구천면주유소  N     서울 강동구 구천면로 357 (암사동)
# 1  1629   GS칼텍스    GS칼텍스㈜직영 신월주유소  N    서울 강동구 양재대로 1323 (성내동)
# 2  1638   SK에너지  주)지유에너지직영 오렌지주유소  N  서울특별시 강동구  성안로 102 (성내동)
# 3  1658   S-OIL             광성주유소  N     서울 강동구 올림픽로 673 (천호동)
# 4  1658   GS칼텍스    대성석유(주)직영길동주유소  N    서울 강동구 천호대로 1168 (둔촌동)

# %%
stations[stations['가격']=='-'] # 가격이 '-'으로 처리된 부분 찾기
# Out:
#    가격      상표                 상호 셀프                          주소
# 17  -   GS칼텍스      명진석유(주)동서울주유소  Y  서울특별시 강동구  천호대로 1456 (상일동)
# 13  -   SK에너지              서강주유소  N        서울 마포구 독막로 134 (창전동)
# 24  -   S-OIL              목동주유소  N       서울 양천구 목동중앙로 125 (목동)
# 25  -   S-OIL              현대주유소  Y      서울 양천구 남부순환로 372 (신월동)
# 33  -   S-OIL              하나주유소  N   서울특별시 영등포구  도림로 236 (신길동)
# 12  -   SK에너지              새한주유소  Y     서울특별시 강북구  도봉로 75 (미아동)
# 11  -    자가상표              세화주유소  N    서울특별시 중구  왕십리로 403 (신당동)
# 17  -  현대오일뱅크        유성주유소(self)  Y        서울 중랑구 망우로 436 (망우동)
# 34  -   S-OIL            하이웨이주유소  N       서울 강서구 공항대로 432 (화곡동)
# 21  -  현대오일뱅크  현대오일뱅크(주)직영신구로주유소  N   서울특별시 구로구  가마산로 293 (구로동)
# 13  -   SK에너지              성부주유소  N     서울 금천구 남부순환로 1280 (가산동)

# %%
stations = stations[stations['가격'] != '-'] # stations변수에 가격이 '-' 부분 제외하고 저장
stations['가격'] = stations['가격'].astype('float') # 가격값은 float형태로 표현
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 512 entries, 0 to 41
# Data columns (total 5 columns):
# 가격    512 non-null float64
# 상표    512 non-null object
# 상호    512 non-null object
# 셀프    512 non-null object
# 주소    512 non-null object
# dtypes: float64(1), object(4)
# memory usage: 24.0+ KB

# %%
# 주유정보 그래프로 그리기 
import seaborn as sns
import matplotlib.pyplot as plt
#한글 폰트 입력
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus']=False

f_path="c:/windows/Fonts/malgun.ttf"
font_name=font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)

# %%
# 셀프주유 여부에 따른 가격 분포. matplotlib에서 제공하는 기본형 그래프
stations.boxplot(column = '가격', by = '셀프', figsize=(12,8));
#그룹 구분 'by'

# %%
plt.figure(figsize=(12,6)) # size 12,6의 그래프 그리기
sns.boxplot(x='셀프', y='가격', data=stations, palette = 'Set3') 
# x축 셀프주유 여부, y축 가격 boxplot그리기. data는 stations
plt.grid() # 눈금선
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='상표', y='가격', hue='셀프', data=stations, palette = 'Set3')
#각 상호별 셀프주유 여부에 따른 가격 비교 그래프, 그룹구분 "hue"
plt.grid()
plt.show()

# %%
# NAVER API이용하기
# NAVER 개발자센터 검색하여 사용자 ID/PW받고 open API이용 가능
import urllib.request
client_id = "--id--"
client_secret = "pw"
encText = urllib.parse.quote("파이썬") #한글을 url형식에 맞게 변경하는 코드
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # 네이버 블로그에서 '파이썬' 검색 url 작성

request = urllib.request.Request(url) # 입력 url에 대한 정보 요청
request.add_header("X-Naver-Client-Id",client_id) # 사용자 정보 보내기
request.add_header("X-Naver-Client-Secret",client_secret)

# %%
response = urllib.request.urlopen(request)
rescode = response.getcode() # 요청에 대한 결과가 올바른지 여부
if(rescode==200):            # 200이라면 올바른 결과 
    response_body = response.read() # 받은 결과 읽어와 저장
    print(response_body.decode('utf-8')) # 결과는 한글을 보기 위해 utf-8로 decode
else:
    print("Error Code:" + rescode) # error라면 오류 정보 출력
# Out:
# {
# "lastBuildDate": "Sat, 18 Aug 2018 17:24:12 +0900",
# "total": 78142,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "&quot;진정한 <b>파이썬</b> 고급 개발자가 되기 위한 능력을... ",
# "link": "http://blog.naver.com/fastcampus?Redirect=Log&amp;logNo=221313946171",
# "description": "<b>파이썬</b>은 백엔드 개발에서부터 데이터 분석에 이르기까지 광범위하게 사용되고 있는 간편하지만 강력한 언어입니다. <b>파이썬</b> 코어를 이해하면 더 깊이 있는 개발이 가능해지고 활용 범위도 확장됩니다. 여기... ",
# "bloggername": "패스트캠퍼스 : FAST CAMPUS",
# "bloggerlink": "http://blog.naver.com/fastcampus",
# "postdate": "20180706"
#
# },
# {
# "title": "<b>파이썬</b>독학 학습 후 달라진 후기",
# "link": "http://blog.naver.com/vhcxjoi2746?Redirect=Log&amp;logNo=221326869715",
# "description": "우연히 <b>파이썬</b>에 대한 이야기를 나눠보았습니다. 요즘은 코딩도 많이 배우고 저학년들도 쉽게 다가갈 수 있다는 장점을 알게 되었죠. 논리적 사고를 기르는데 아주 큰 기여도가 높은 <b>파이썬</b>! 프로그래밍 언어... ",
# "bloggername": "GAINMIGA",
# "bloggerlink": "http://blog.naver.com/vhcxjoi2746",
# "postdate": "20180726"
#
# },
# {
# "title": "부산 : C언어 / <b>파이썬</b> / 자바 / 프로그래밍 배울 수 있는곳은?",
# "link": "http://blog.naver.com/minjeong86?Redirect=Log&amp;logNo=221334742207",
# "description": "부산 C언어 <b>파이썬</b> 자바 프로그래밍 배울 수 있는곳은? 안녕하세요! IT쉽게 알려주는 세현쌤입니다!... 대표적으로는 C언어와 C++, 자바, <b>파이썬</b> 등등! 이런 언어들은 어떤 프로그램을 만드냐에 따라서 사용하는... ",
# "bloggername": "민뎡-밥상과의대화창",
# "bloggerlink": "http://blog.naver.com/minjeong86",
# "postdate": "20180808"
#
# },
# {
# "title": "<b>파이썬</b>학원 공부가 걱정되요",
# "link": "http://blog.naver.com/wkdrptn1000?Redirect=Log&amp;logNo=221309275441",
# "description": "바로 <b>파이썬</b>이라고 해요~ 간결한 문법으로 초보자가 이해하기 쉬우며 다양한 분야에 활용할 수 있기... 개발한 <b>파이썬</b>은 문법도 다른 프로그래밍 언어에 비해 간결 할 뿐 아니라 표현하는 구조도 복잡하지 않아... ",
# "bloggername": "미친과일의 파라다이스",
# "bloggerlink": "http://blog.naver.com/wkdrptn1000",
# "postdate": "20180629"
#
# },
# {
# "title": "<b>파이썬</b> 시작하기",
# "link": "http://blog.naver.com/3yong2ya?Redirect=Log&amp;logNo=221330118869",
# "description": "이제서야 <b>파이썬</b>을 접해본다. 이 글은 30분동안 몇가지 예제 돌려보고 The Python Standard Library 라는 문서를 보면서 쓰는 글이다. https://docs.python.org/3/library/index.html <b>파이썬</b> 2와 3는... ",
# "bloggername": "소비자가 되지 말고, 생산자가 되자!",
# "bloggerlink": "http://blog.naver.com/3yong2ya",
# "postdate": "20180731"
#
# },
# {
# "title": "[슬기로운 코딩생활] with <b>파이썬</b>-으랏차차 기초편",
# "link": "http://blog.naver.com/willout?Redirect=Log&amp;logNo=221300282869",
# "description": "슬기로운 코딩 생활 with <b>파이썬</b> 으랏차차 기초편 저자 김정욱, 김준석 출판 루비페이퍼 발매 2018.05.15.... 수업으로 <b>파이썬</b>을 하더라구요. 지금 공대로 가려는 고등학생들도 대학입학을 코앞에 앞두고... ",
# "bloggername": "구름한잔",
# "bloggerlink": "http://blog.naver.com/willout",
# "postdate": "20180616"
#
# },
# {
# "title": "<b>파이썬</b>, 아나콘다 설치하기",
# "link": "http://blog.naver.com/kiddwannabe?Redirect=Log&amp;logNo=221154599192",
# "description": "<b>파이썬</b> 및 아나콘다 / 쥬피터노트북 설치에 대해 알아보겠습니다. 1. <b>파이썬</b>? - <b>파이썬</b>의 장점 : 쉽다. 무료. 사람들이 많이 쓴다. ① (다른 언어에 비해) 코딩하는 것이 참 쉽습니다. 어떻게 보면 융통성?... ",
# "bloggername": "데이터공방 - 파이썬/크롤링/머신러닝/시각화",
# "bloggerlink": "http://blog.naver.com/kiddwannabe",
# "postdate": "20171204"
#
# },
# {
# "title": "오늘의 일상기획, 문과생이 <b>파이썬</b>을 배운다는 것은.",
# "link": "http://blog.naver.com/herjayoung?Redirect=Log&amp;logNo=221320214060",
# "description": "<b>파이썬</b>! 내가 한번 정복해보리라! 요즘 <b>파이썬</b>을 배우고 있다. 며칠 전 트렌토리를 들으면서 내가 생각이 들었던 몇 가지가 있었다. 앞으로 코딩과 영상, 디자인을 잘 한다면 경쟁력이 있을 것 같다는 생각이... ",
# "bloggername": "성 장 하 는 일 상 기 획 자",
# "bloggerlink": "http://blog.naver.com/herjayoung",
# "postdate": "20180716"
#
# },
# {
# "title": "[<b>파이썬</b>] 윈도우10에서 jupyter lab 이용하기",
# "link": "http://mcchae.egloos.com/11302331",
# "description": "ipython 이라는 것은 <b>파이썬</b>의 확장 쉘로서 2001년 부터 시작되었습니다. [1], [2].. 등과 같이 명령... 이것이 다시 2014년에 Jupyter Notebook 이라고 하여 보여주는 형태의 발전 뿐만 아니라 <b>파이썬</b>을... ",
# "bloggername": "지훈현서",
# "bloggerlink": "http://mcchae.egloos.com/",
# "postdate": "20180721"
#
# },
# {
# "title": "[간단팁] - 비주얼 스튜디오에서 <b>파이썬</b> 이용하기... ",
# "link": "http://blog.naver.com/rickman2?Redirect=Log&amp;logNo=221331073408",
# "description": "여러분들은 어떤 IDE를 기반으로 <b>파이썬</b>을 개발하시나요? 저는 윈도우에 친숙한 비주얼(Visual Studio)를 통해서, <b>파이썬</b>을 개발하고 있습니다. 초기 <b>파이썬</b>을 개발할 당시 Visual Studio 2015에서와 크게... ",
# "bloggername": "Data Miner",
# "bloggerlink": "http://blog.naver.com/rickman2",
# "postdate": "20180802"
#
# }
# ]
# }

# %%
# 책 정보에서 '파이썬' 검색
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/book?query=" + encText

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request)
rescode = response.getcode()
print(response_body.decode('utf-8'))
# Out:
# {
# "lastBuildDate": "Sat, 18 Aug 2018 17:24:12 +0900",
# "total": 78142,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "&quot;진정한 <b>파이썬</b> 고급 개발자가 되기 위한 능력을... ",
# "link": "http://blog.naver.com/fastcampus?Redirect=Log&amp;logNo=221313946171",
# "description": "<b>파이썬</b>은 백엔드 개발에서부터 데이터 분석에 이르기까지 광범위하게 사용되고 있는 간편하지만 강력한 언어입니다. <b>파이썬</b> 코어를 이해하면 더 깊이 있는 개발이 가능해지고 활용 범위도 확장됩니다. 여기... ",
# "bloggername": "패스트캠퍼스 : FAST CAMPUS",
# "bloggerlink": "http://blog.naver.com/fastcampus",
# "postdate": "20180706"
#
# },
# {
# "title": "<b>파이썬</b>독학 학습 후 달라진 후기",
# "link": "http://blog.naver.com/vhcxjoi2746?Redirect=Log&amp;logNo=221326869715",
# "description": "우연히 <b>파이썬</b>에 대한 이야기를 나눠보았습니다. 요즘은 코딩도 많이 배우고 저학년들도 쉽게 다가갈 수 있다는 장점을 알게 되었죠. 논리적 사고를 기르는데 아주 큰 기여도가 높은 <b>파이썬</b>! 프로그래밍 언어... ",
# "bloggername": "GAINMIGA",
# "bloggerlink": "http://blog.naver.com/vhcxjoi2746",
# "postdate": "20180726"
#
# },
# {
# "title": "부산 : C언어 / <b>파이썬</b> / 자바 / 프로그래밍 배울 수 있는곳은?",
# "link": "http://blog.naver.com/minjeong86?Redirect=Log&amp;logNo=221334742207",
# "description": "부산 C언어 <b>파이썬</b> 자바 프로그래밍 배울 수 있는곳은? 안녕하세요! IT쉽게 알려주는 세현쌤입니다!... 대표적으로는 C언어와 C++, 자바, <b>파이썬</b> 등등! 이런 언어들은 어떤 프로그램을 만드냐에 따라서 사용하는... ",
# "bloggername": "민뎡-밥상과의대화창",
# "bloggerlink": "http://blog.naver.com/minjeong86",
# "postdate": "20180808"
#
# },
# {
# "title": "<b>파이썬</b>학원 공부가 걱정되요",
# "link": "http://blog.naver.com/wkdrptn1000?Redirect=Log&amp;logNo=221309275441",
# "description": "바로 <b>파이썬</b>이라고 해요~ 간결한 문법으로 초보자가 이해하기 쉬우며 다양한 분야에 활용할 수 있기... 개발한 <b>파이썬</b>은 문법도 다른 프로그래밍 언어에 비해 간결 할 뿐 아니라 표현하는 구조도 복잡하지 않아... ",
# "bloggername": "미친과일의 파라다이스",
# "bloggerlink": "http://blog.naver.com/wkdrptn1000",
# "postdate": "20180629"
#
# },
# {
# "title": "<b>파이썬</b> 시작하기",
# "link": "http://blog.naver.com/3yong2ya?Redirect=Log&amp;logNo=221330118869",
# "description": "이제서야 <b>파이썬</b>을 접해본다. 이 글은 30분동안 몇가지 예제 돌려보고 The Python Standard Library 라는 문서를 보면서 쓰는 글이다. https://docs.python.org/3/library/index.html <b>파이썬</b> 2와 3는... ",
# "bloggername": "소비자가 되지 말고, 생산자가 되자!",
# "bloggerlink": "http://blog.naver.com/3yong2ya",
# "postdate": "20180731"
#
# },
# {
# "title": "[슬기로운 코딩생활] with <b>파이썬</b>-으랏차차 기초편",
# "link": "http://blog.naver.com/willout?Redirect=Log&amp;logNo=221300282869",
# "description": "슬기로운 코딩 생활 with <b>파이썬</b> 으랏차차 기초편 저자 김정욱, 김준석 출판 루비페이퍼 발매 2018.05.15.... 수업으로 <b>파이썬</b>을 하더라구요. 지금 공대로 가려는 고등학생들도 대학입학을 코앞에 앞두고... ",
# "bloggername": "구름한잔",
# "bloggerlink": "http://blog.naver.com/willout",
# "postdate": "20180616"
#
# },
# {
# "title": "<b>파이썬</b>, 아나콘다 설치하기",
# "link": "http://blog.naver.com/kiddwannabe?Redirect=Log&amp;logNo=221154599192",
# "description": "<b>파이썬</b> 및 아나콘다 / 쥬피터노트북 설치에 대해 알아보겠습니다. 1. <b>파이썬</b>? - <b>파이썬</b>의 장점 : 쉽다. 무료. 사람들이 많이 쓴다. ① (다른 언어에 비해) 코딩하는 것이 참 쉽습니다. 어떻게 보면 융통성?... ",
# "bloggername": "데이터공방 - 파이썬/크롤링/머신러닝/시각화",
# "bloggerlink": "http://blog.naver.com/kiddwannabe",
# "postdate": "20171204"
#
# },
# {
# "title": "오늘의 일상기획, 문과생이 <b>파이썬</b>을 배운다는 것은.",
# "link": "http://blog.naver.com/herjayoung?Redirect=Log&amp;logNo=221320214060",
# "description": "<b>파이썬</b>! 내가 한번 정복해보리라! 요즘 <b>파이썬</b>을 배우고 있다. 며칠 전 트렌토리를 들으면서 내가 생각이 들었던 몇 가지가 있었다. 앞으로 코딩과 영상, 디자인을 잘 한다면 경쟁력이 있을 것 같다는 생각이... ",
# "bloggername": "성 장 하 는 일 상 기 획 자",
# "bloggerlink": "http://blog.naver.com/herjayoung",
# "postdate": "20180716"
#
# },
# {
# "title": "[<b>파이썬</b>] 윈도우10에서 jupyter lab 이용하기",
# "link": "http://mcchae.egloos.com/11302331",
# "description": "ipython 이라는 것은 <b>파이썬</b>의 확장 쉘로서 2001년 부터 시작되었습니다. [1], [2].. 등과 같이 명령... 이것이 다시 2014년에 Jupyter Notebook 이라고 하여 보여주는 형태의 발전 뿐만 아니라 <b>파이썬</b>을... ",
# "bloggername": "지훈현서",
# "bloggerlink": "http://mcchae.egloos.com/",
# "postdate": "20180721"
#
# },
# {
# "title": "[간단팁] - 비주얼 스튜디오에서 <b>파이썬</b> 이용하기... ",
# "link": "http://blog.naver.com/rickman2?Redirect=Log&amp;logNo=221331073408",
# "description": "여러분들은 어떤 IDE를 기반으로 <b>파이썬</b>을 개발하시나요? 저는 윈도우에 친숙한 비주얼(Visual Studio)를 통해서, <b>파이썬</b>을 개발하고 있습니다. 초기 <b>파이썬</b>을 개발할 당시 Visual Studio 2015에서와 크게... ",
# "bloggername": "Data Miner",
# "bloggerlink": "http://blog.naver.com/rickman2",
# "postdate": "20180802"
#
# }
# ]
# }

# %%
#영화 정보에서 '파이썬'검색
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/movie?query=" + encText

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request)
rescode = response.getcode()
print(response.read().decode('utf-8'))
# Out:
# {
# "lastBuildDate": "Sat, 18 Aug 2018 17:28:03 +0900",
# "total": 1,
# "start": 1,
# "display": 1,
# "items": [
# {
# "title": "<b>파이썬</b> 앤 가드",
# "link": "https://movie.naver.com/movie/bi/mi/basic.nhn?code=152070",
# "image": "https://ssl.pstatic.net/imgmovie/mdi/mit110/1520/152070_P01_145336.jpg",
# "subtitle": "PYTHON AND GUARD",
# "pubDate": "2015",
# "director": "안톤 디아코프|",
# "actor": "",
# "userRating": "0.00"
#
# }
# ]
# }

# %%
#쇼핑에서 '축구화'검색
encText = urllib.parse.quote("축구화")
url = "https://openapi.naver.com/v1/search/shop?query=" + encText

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request)
rescode = response.getcode()
print(response.read().decode('utf-8'))
# Out:
# {
# "lastBuildDate": "Sat, 18 Aug 2018 17:28:13 +0900",
# "total": 576012,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "나이키 팬텀 비전 프로 DF HG <b>축구화</b> AQ9289 001",
# "link": "http://search.shopping.naver.com/gate.nhn?id=14991364602",
# "image": "https://shopping-phinf.pstatic.net/main_1499136/14991364602.20180807160004.jpg",
# "lprice": "133130",
# "hprice": "269000",
# "mallName": "네이버",
# "productId": "14991364602",
# "productType": "1"
#
# },
# {
# "title": "나이키 팬텀 비전 프로 DF FG <b>축구화</b> AO3266 060",
# "link": "http://search.shopping.naver.com/gate.nhn?id=14991379670",
# "image": "https://shopping-phinf.pstatic.net/main_1499137/14991379670.20180807160448.jpg",
# "lprice": "119510",
# "hprice": "179000",
# "mallName": "네이버",
# "productId": "14991379670",
# "productType": "1"
#
# },
# {
# "title": "나이키 티엠포 레전드 7 엘리트 FG <b>축구화</b> AH7238 006",
# "link": "http://search.shopping.naver.com/gate.nhn?id=14999713587",
# "image": "https://shopping-phinf.pstatic.net/main_1499971/14999713587.20180808163214.jpg",
# "lprice": "187120",
# "hprice": "269000",
# "mallName": "네이버",
# "productId": "14999713587",
# "productType": "1"
#
# },
# {
# "title": "나이키 팬텀 비전 아카데미 DF HG <b>축구화</b> AO3253 060",
# "link": "http://search.shopping.naver.com/gate.nhn?id=14999554700",
# "image": "https://shopping-phinf.pstatic.net/main_1499955/14999554700.20180808153640.jpg",
# "lprice": "72760",
# "hprice": "169000",
# "mallName": "네이버",
# "productId": "14999554700",
# "productType": "1"
#
# },
# {
# "title": "아디다스 엑스 18.1 FG <b>축구화</b> DB2248",
# "link": "http://search.shopping.naver.com/gate.nhn?id=14936583081",
# "image": "https://shopping-phinf.pstatic.net/main_1493658/14936583081.20180731165337.jpg",
# "lprice": "154860",
# "hprice": "312900",
# "mallName": "네이버",
# "productId": "14936583081",
# "productType": "1"
#
# },
# {
# "title": "나이키 머큐리얼 슈퍼플라이 6 클럽 MG GS사이즈 호날두 <b>축구화</b>",
# "link": "http://search.shopping.naver.com/gate.nhn?id=80925958281",
# "image": "https://shopping-phinf.pstatic.net/main_8092595/80925958281.jpg",
# "lprice": "67900",
# "hprice": "0",
# "mallName": "구루브",
# "productId": "80925958281",
# "productType": "2"
#
# },
# {
# "title": "아디다스 네메시스 18.4 FXG <b>축구화</b> DB2115",
# "link": "http://search.shopping.naver.com/gate.nhn?id=14999829917",
# "image": "https://shopping-phinf.pstatic.net/main_1499982/14999829917.20180808165022.jpg",
# "lprice": "46750",
# "hprice": "79000",
# "mallName": "네이버",
# "productId": "14999829917",
# "productType": "1"
#
# },
# {
# "title": "BB6954 아디다스 엑스 18.3 HG",
# "link": "http://search.shopping.naver.com/gate.nhn?id=14954657472",
# "image": "https://shopping-phinf.pstatic.net/main_1495465/14954657472.jpg",
# "lprice": "75700",
# "hprice": "0",
# "mallName": "CJmall",
# "productId": "14954657472",
# "productType": "2"
#
# },
# {
# "title": "나이키 팬텀 비젼 엘리트 DF FG - AO3262-060(화이트레드/그레이)",
# "link": "http://search.shopping.naver.com/gate.nhn?id=80798470988",
# "image": "https://shopping-phinf.pstatic.net/main_8079847/80798470988.1.jpg",
# "lprice": "309000",
# "hprice": "0",
# "mallName": "에프에이사커",
# "productId": "80798470988",
# "productType": "2"
#
# },
# {
# "title": "나이키 레전드 7 아카데미 HG <b>축구화</b> AO9880 107",
# "link": "http://search.shopping.naver.com/gate.nhn?id=14429351803",
# "image": "https://shopping-phinf.pstatic.net/main_1442935/14429351803.20180531180407.jpg",
# "lprice": "45580",
# "hprice": "149000",
# "mallName": "네이버",
# "productId": "14429351803",
# "productType": "1"
#
# }
# ]
# }

# %%
# API를 이용하는 함수 구성
import datetime
def get_request_url(API_url):           # API_url을 인자로 하는 get_request_url함수 선언 . 
    client_id = "kUMekrHWTsTF09Meg3Sj"
    client_secret = "DYchAGoQGY"
    
    request = urllib.request.Request(API_url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)

    response = urllib.request.urlopen(request)
    if response.getcode()==200:
        print("[%s] Url Request Success" %datetime.datetime.now()) #현재 날짜 정보 [ ] 안에 입력
        return response.read().decode('utf-8')                     #불러온 내용을 utf-8로 decode한 결과 반출
    else:
        print("[%s] Error --------------" %datetime.datetime.now())
        return None

# %%
encText = urllib.parse.quote('몰스킨') # 검색어
API_url = "https://openapi.naver.com/v1/search/shop.json?query=" + encText #함수 인자
print(get_request_url(API_url)) # 함수 호출하여 결과 출력
# Out:
# [2018-08-18 17:57:43.660195] Url Request Success
# {
# "lastBuildDate": "Sat, 18 Aug 2018 17:57:41 +0900",
# "total": 22495,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>몰스킨</b> 클래식 룰드 줄지",
# "link": "http://search.shopping.naver.com/gate.nhn?id=7398991731",
# "image": "https://shopping-phinf.pstatic.net/main_7398991/7398991731.20180112135400.jpg",
# "lprice": "15700",
# "hprice": "40530",
# "mallName": "네이버",
# "productId": "7398991731",
# "productType": "1"
#
# },
# {
# "title": "<b>몰스킨</b> 까이에 엑스라지 다이어리",
# "link": "http://search.shopping.naver.com/gate.nhn?id=10010203158",
# "image": "https://shopping-phinf.pstatic.net/main_1001020/10010203158.20160704125951.jpg",
# "lprice": "8800",
# "hprice": "34100",
# "mallName": "네이버",
# "productId": "10010203158",
# "productType": "1"
#
# },
# {
# "title": "KM <b>몰스킨</b> 클래식 룰드 줄지 소프트커버 라지 노트북 9788",
# "link": "http://search.shopping.naver.com/gate.nhn?id=13372539964",
# "image": "https://shopping-phinf.pstatic.net/main_1337253/13372539964.1.jpg",
# "lprice": "19400",
# "hprice": "0",
# "mallName": "N펀키보이",
# "productId": "13372539964",
# "productType": "2"
#
# },
# {
# "title": "<b>몰스킨</b> 피너츠 데일리 2018 코랄오렌지 라지 55532",
# "link": "http://search.shopping.naver.com/gate.nhn?id=13539545478",
# "image": "https://shopping-phinf.pstatic.net/main_1353954/13539545478.jpg",
# "lprice": "8990",
# "hprice": "0",
# "mallName": "인터파크",
# "productId": "13539545478",
# "productType": "2"
#
# },
# {
# "title": "<b>몰스킨</b> 2017 위클리 18개월 그린 하드 다이어리",
# "link": "http://search.shopping.naver.com/gate.nhn?id=10010117049",
# "image": "https://shopping-phinf.pstatic.net/main_1001011/10010117049.20160704125551.jpg",
# "lprice": "20000",
# "hprice": "228500",
# "mallName": "네이버",
# "productId": "10010117049",
# "productType": "1"
#
# },
# {
# "title": "<b>몰스킨</b> 2018 스누피 다이어리",
# "link": "http://search.shopping.naver.com/gate.nhn?id=12606204666",
# "image": "https://shopping-phinf.pstatic.net/main_1260620/12606204666.1.jpg",
# "lprice": "12000",
# "hprice": "0",
# "mallName": "홀세일스토어",
# "productId": "12606204666",
# "productType": "2"
#
# },
# {
# "title": "[한정판]<b>몰스킨</b> 노트 닥터수스 하드 룰드 라지 블루",
# "link": "http://search.shopping.naver.com/gate.nhn?id=14534272532",
# "image": "https://shopping-phinf.pstatic.net/main_1453427/14534272532.jpg",
# "lprice": "35739",
# "hprice": "0",
# "mallName": "신세계몰",
# "productId": "14534272532",
# "productType": "2"
#
# },
# {
# "title": "<b>몰스킨</b> 피너츠 데일리 2018 코랄오렌지 라지 55532",
# "link": "http://search.shopping.naver.com/gate.nhn?id=80566520418",
# "image": "https://shopping-phinf.pstatic.net/main_8056652/80566520418.1.jpg",
# "lprice": "9900",
# "hprice": "0",
# "mallName": "유에스몰코리아",
# "productId": "80566520418",
# "productType": "2"
#
# },
# {
# "title": "@@정품 무료각인@@[<b>몰스킨</b>/2018∼19]해리포터 위클리(18개월)-라지",
# "link": "http://search.shopping.naver.com/gate.nhn?id=14998455956",
# "image": "https://shopping-phinf.pstatic.net/main_1499845/14998455956.jpg",
# "lprice": "35140",
# "hprice": "0",
# "mallName": "현대Hmall",
# "productId": "14998455956",
# "productType": "2"
#
# },
# {
# "title": "[핫트랙스] <b>몰스킨</b> 2019위클리(18M)/L.그린 하드 L",
# "link": "http://search.shopping.naver.com/gate.nhn?id=14992815194",
# "image": "https://shopping-phinf.pstatic.net/main_1499281/14992815194.jpg",
# "lprice": "33440",
# "hprice": "0",
# "mallName": "11번가",
# "productId": "14992815194",
# "productType": "2"
#
# }
# ]
# }

# %%
# 함수와 함수인자 이용
def get_search_result(api_node, search_text, start_num, disp_num):
    base = "https://openapi.naver.com/v1/search/"
    node = "/" + api_node + ".json"
    param_query = "?query=" + urllib.parse.quote(search_text)
    param_start = "&start=" + str(start_num)
    param_disp = "&display=" + str(disp_num)
    
    url = base + node + param_query + param_start+ param_disp
    
    print(url)

# %%
get_search_result('shop', 'TEST', 10, 3) 
# 쇼핑 사이트에서 TEST를 검색어로 하여 10번째 쇼핑 정보부터 3개만 보여줄 것.
# Out:
# https://openapi.naver.com/v1/search//shop.json?query=TEST&start=10&display=3

# %%
import json
def get_search_result(api_node, search_text, start_num, disp_num):
    
    base = "https://openapi.naver.com/v1/search"
    node = "/" + api_node + ".json"
    param_query = "?query=" + urllib.parse.quote(search_text)
    param_start = "&start=" + str(start_num)
    param_disp = "&display=" + str(disp_num)
    
    url = base + node + param_query + param_start + param_disp
    
    # 요청이 올바르게 왔는지 확인하는 과정
    getting_data = get_request_url(url) 
    
    if (getting_data == None):
        return None
    else:
        return json.loads(getting_data)

# %%
search_result = get_search_result('shop', '몰스킨', 1, 2)
# naver쇼핑에서 몰스킨을 검색어로 하고 첫번째 정보부터 2개만 불러오기
# Out:
# [2018-08-18 17:58:19.924901] Url Request Success

# %%
search_result # 검색결과
# Out:
# {'display': 2,
#  'items': [{'hprice': '40530',
#    'image': 'https://shopping-phinf.pstatic.net/main_7398991/7398991731.20180112135400.jpg',
#    'link': 'http://search.shopping.naver.com/gate.nhn?id=7398991731',
#    'lprice': '15700',
#    'mallName': '네이버',
#    'productId': '7398991731',
#    'productType': '1',
#    'title': '<b>몰스킨</b> 클래식 룰드 줄지'},
#   {'hprice': '34100',
#    'image': 'https://shopping-phinf.pstatic.net/main_1001020/10010203158.20160704125951.jpg',
#    'link': 'http://search.shopping.naver.com/gate.nhn?id=10010203158',
#    'lprice': '8800',
#    'mallName': '네이버',
#    'productId': '10010203158',
#    'productType': '1',
#    'title': '<b>몰스킨</b> 까이에 엑스라지 다이어리'}],
#  'lastBuildDate': 'Sat, 18 Aug 2018 17:58:18 +0900',
#  'start': 1,
#  'total': 22495}
