# %%
# API를 이용하는 함수 구성
import urllib.request
import datetime
def get_request_url(API_url):           # API_url을 인자로 하는 get_request_url함수 선언 . 
    client_id = "kUMekrHWTsTF09Meg3Sj"  # API 등록 ID
    client_secret = "DYchAGoQGY"        #API 이용 pw
    
    request = urllib.request.Request(API_url) # API_url을 받아 페이지 정보 요청
    request.add_header("X-Naver-Client-Id",client_id) # header에 등록 정보 포함하여 요청
    request.add_header("X-Naver-Client-Secret",client_secret)

    response = urllib.request.urlopen(request) # 요청의 결과를 response 함수에 저장
    if response.getcode()==200: # 결과가 200(참)이면 아래 내용 출력
        print("[%s] Url Request Success" %datetime.datetime.now()) #현재 날짜 정보 [ ] 안에 입력
        return response.read().decode('utf-8')                     #불러온 내용을 utf-8로 decode한 결과 반출
    else:
        print("[%s] Error --------------" %datetime.datetime.now())
        return None

# %%
import json
def get_search_result(api_node, search_text, start_num, disp_num):
    #api_node, search_text, start_num, disp_num을 인자로 하는 get_search_result함수 선언
    #url을 부분별로 나눠 인자를 포함하는 변수 만들기
    base = "https://openapi.naver.com/v1/search" 
    node = "/" + api_node + ".json"              #api_node는 shop, book, movie등 검색영역 
    param_query = "?query=" + urllib.parse.quote(search_text) #search_text는 입력을 받아 url에 맞는 코드로 변경
    param_start = "&start=" + str(start_num)
    param_disp = "&display=" + str(disp_num)
    
    url = base + node + param_query + param_start + param_disp
    
    # 요청이 올바르게 왔는지 확인하는 과정
    getting_data = get_request_url(url) 
    #get_request_url 함수가 url 변수를 인자로 받아 결과 변수에 저장
    if (getting_data == None): # 결과가 없다면 none 반환
        return None
    else:
        return json.loads(getting_data) 
    # 결과가 있다면 json형태로 반환
    #json파일은 dictionary형과 list형의 조합으로 구성
    # key값과 리스트의 index 값을 통해 value탐색

# %%
#함수 동작
search_result = get_search_result('shop', '몰스킨', 1, 2)

# naver쇼핑에서 몰스킨을 검색어로 하고 첫번째 정보부터 2개만 불러오기
# Out:
# [2018-08-25 14:18:28.607947] Url Request Success

# %%
search_result
# Out:
# {'display': 2,
#  'items': [{'hprice': '41130',
#    'image': 'https://shopping-phinf.pstatic.net/main_7398991/7398991731.20180112135400.jpg',
#    'link': 'http://search.shopping.naver.com/gate.nhn?id=7398991731',
#    'lprice': '15690',
#    'mallName': '네이버',
#    'productId': '7398991731',
#    'productType': '1',
#    'title': '<b>몰스킨</b> 클래식 룰드 줄지'},
#   {'hprice': '0',
#    'image': 'https://shopping-phinf.pstatic.net/main_1337253/13372539964.1.jpg',
#    'link': 'http://search.shopping.naver.com/gate.nhn?id=13372539964',
#    'lprice': '19400',
#    'mallName': 'N펀키보이',
#    'productId': '13372539964',
#    'productType': '2',
#    'title': 'KM <b>몰스킨</b> 클래식 룰드 줄지 소프트커버 라지 노트북 9788'}],
#  'lastBuildDate': 'Sat, 25 Aug 2018 14:18:28 +0900',
#  'start': 1,
#  'total': 22531}

# %%
search_result["items"]
# json 포맷에서 'items' key의 value값인 list 출력
# Out:
# [{'hprice': '41130',
#   'image': 'https://shopping-phinf.pstatic.net/main_7398991/7398991731.20180112135400.jpg',
#   'link': 'http://search.shopping.naver.com/gate.nhn?id=7398991731',
#   'lprice': '15690',
#   'mallName': '네이버',
#   'productId': '7398991731',
#   'productType': '1',
#   'title': '<b>몰스킨</b> 클래식 룰드 줄지'},
#  {'hprice': '0',
#   'image': 'https://shopping-phinf.pstatic.net/main_1337253/13372539964.1.jpg',
#   'link': 'http://search.shopping.naver.com/gate.nhn?id=13372539964',
#   'lprice': '19400',
#   'mallName': 'N펀키보이',
#   'productId': '13372539964',
#   'productType': '2',
#   'title': 'KM <b>몰스킨</b> 클래식 룰드 줄지 소프트커버 라지 노트북 9788'}]

# %%
search_result['start'], search_result['total'], search_result['display']
# search_result에서 start, total, display key의 value 출력
# Out:
# (1, 22531, 2)

# %%
search_result['items'][0]['title']
# items key의 첫번째 value값 내에서 title key의 value값 출력
# Out:
# '<b>몰스킨</b> 클래식 룰드 줄지'

# %%
search_result['items'][0]['lprice'], search_result['items'][0]['hprice']
#items key의 첫번째 value값에서 hprice, lprice key의 value출력
# Out:
# ('15690', '41130')

# %%
search_result['items'][0]['title'].replace('<b>','')
#결과에서 <b>를 공백없음으로 치환
# Out:
# '몰스킨</b> 클래식 룰드 줄지'

# %%
def delete_tag(input_str): # 함수선언
    input_str = input_str.replace('<b>','') # <b>를 공백없음으로 대체
    input_str = input_str.replace('</b>','') # </b>를 공백없음으로 대체
    return input_str #치환한 결과 반환

# %%
import pandas as pd
def get_fields(post): #함수 선언
    #빈 list 만들기
    title = [] 
    link = []
    lprice = []
    hprice = []
    
    # post인자를 받는 반복문 작성
    for each in post:
        title.append(delete_tag(each['title'])) # 'title'key의 value값을 가져와 delet_tag 함수 수행한 결과 저장
        link.append(each['link'])               # 'link' key의 value값 저장
        lprice.append(each['lprice'])           # 'lprive' key의 value값 저장
        hprice.append(each['hprice'])           #  'hprice'key의 value값 저장
    
    # 반복문의 결과로 dataframe을 만들고 columns 이름을 title, lprice, hprice로 한다.
    result_pd = pd.DataFrame({'title':title,'lprice':lprice, 'hprice':hprice, 'link':link}, columns = ['title', 'lprice', 'hprice','link'])
    
    return result_pd #결과 반출

# %%
get_fields(search_result['items'])
# search_result의 'items'key 결과를 get_fields 인자로 갖는 함수호출
# Out:
#                                 title lprice hprice  \
# 0                       몰스킨 클래식 룰드 줄지  15690  41130
# 1  KM 몰스킨 클래식 룰드 줄지 소프트커버 라지 노트북 9788  19400      0
#
#                                                 link
# 0  http://search.shopping.naver.com/gate.nhn?id=7...
# 1  http://search.shopping.naver.com/gate.nhn?id=1...

# %%
#위의 함수에 인자 재입력 결과
search_result = get_search_result('shop','몰스킨','1','2')
tmp1 = get_fields(search_result['items'])
tmp1
# Out:
# [2018-08-25 14:29:37.287297] Url Request Success
#                                 title lprice hprice  \
# 0                       몰스킨 클래식 룰드 줄지  15690  41130
# 1  KM 몰스킨 클래식 룰드 줄지 소프트커버 라지 노트북 9788  19400      0
#
#                                                 link
# 0  http://search.shopping.naver.com/gate.nhn?id=7...
# 1  http://search.shopping.naver.com/gate.nhn?id=1...

# %%
# 위와 다른 인자값을 입력한 함수 호출
search_result = get_search_result('shop','몰스킨','3','2')
tmp2 = get_fields(search_result['items'])
tmp2
# Out:
# [2018-08-25 14:30:05.682184] Url Request Success
#                           title lprice  hprice  \
# 0             몰스킨 까이에 엑스라지 다이어리   8700   34100
# 1  몰스킨 2017 위클리 18개월 그린 하드 다이어리  20000  228500
#
#                                                 link
# 0  http://search.shopping.naver.com/gate.nhn?id=1...
# 1  http://search.shopping.naver.com/gate.nhn?id=1...

# %%
tmp1.append(tmp2)
#tmp2결과를 tmp1에 추가
# Out:
#                                 title lprice  hprice  \
# 0                       몰스킨 클래식 룰드 줄지  15690   41130
# 1  KM 몰스킨 클래식 룰드 줄지 소프트커버 라지 노트북 9788  19400       0
# 0                   몰스킨 까이에 엑스라지 다이어리   8700   34100
# 1        몰스킨 2017 위클리 18개월 그린 하드 다이어리  20000  228500
#
#                                                 link
# 0  http://search.shopping.naver.com/gate.nhn?id=7...
# 1  http://search.shopping.naver.com/gate.nhn?id=1...
# 0  http://search.shopping.naver.com/gate.nhn?id=1...
# 1  http://search.shopping.naver.com/gate.nhn?id=1...

# %%
# 네이버 쇼핑에서 몰스킨에 대한 100개의 검색결과 출력
result_mol = []
for n in range(1,100,10):
    # 1~100까지 10간격으로 변수 입력 (1, 11, 21, 31, 41) , 10개씩 결과 잘라 입력 
    search_result = get_search_result('shop','몰스킨', n,'10')
    # 네이버 쇼핑에서 몰스킨을 검색하고 n부터 10개 검색결과 변수저장 
    result_mol.append(get_fields(search_result['items']))
    # 각 결과에서 item key를 인자로 갖는 함수 호출하여 빈 list에 저장
result_mol = pd.concat(result_mol)
    # concat10개씩 분할된 결과를 붙이기
# Out:
# [2018-08-25 14:32:45.704082] Url Request Success
# [2018-08-25 14:32:45.860662] Url Request Success
# [2018-08-25 14:32:46.029212] Url Request Success
# [2018-08-25 14:32:46.266579] Url Request Success
# [2018-08-25 14:32:46.474023] Url Request Success
# [2018-08-25 14:32:46.664618] Url Request Success
# [2018-08-25 14:32:46.854025] Url Request Success
# [2018-08-25 14:32:47.062347] Url Request Success
# [2018-08-25 14:32:47.278629] Url Request Success
# [2018-08-25 14:32:47.501306] Url Request Success

# %%
result_mol.head()
# Out:
#                                 title lprice  hprice  \
# 0                       몰스킨 클래식 룰드 줄지  15690   41130
# 1  KM 몰스킨 클래식 룰드 줄지 소프트커버 라지 노트북 9788  19400       0
# 2                   몰스킨 까이에 엑스라지 다이어리   8700   34100
# 3        몰스킨 2017 위클리 18개월 그린 하드 다이어리  20000  228500
# 4                   몰스킨 2018 스누피 다이어리  12000       0
#
#                                                 link
# 0  http://search.shopping.naver.com/gate.nhn?id=7...
# 1  http://search.shopping.naver.com/gate.nhn?id=1...
# 2  http://search.shopping.naver.com/gate.nhn?id=1...
# 3  http://search.shopping.naver.com/gate.nhn?id=1...
# 4  http://search.shopping.naver.com/gate.nhn?id=1...

# %%
result_mol = result_mol.reset_index(drop=True) 
# 0-9가 반복되는 index를 0-99까지 index 재설정
result_mol
# Out:
#                                                 title  lprice  hprice  \
# 0                                       몰스킨 클래식 룰드 줄지   15690   41130
# 1                  KM 몰스킨 클래식 룰드 줄지 소프트커버 라지 노트북 9788   19400       0
# 2                                   몰스킨 까이에 엑스라지 다이어리    8700   34100
# 3                        몰스킨 2017 위클리 18개월 그린 하드 다이어리   20000  228500
# 4                                   몰스킨 2018 스누피 다이어리   12000       0
# 5                        [한정판]몰스킨 슈퍼마리오 하드룰드L 풀스크린 블루   33520       0
# 6              몰스킨 클래식 룰드 줄지 소프트커버 라지 9788-88370-7162   19000       0
# 7                     몰스킨 피너츠 데일리 2018 코랄오렌지 라지 55532    8990       0
# 8                    [한정판] 몰스킨 노트 아톰 하드커버 룰드 라지 다크그레이   34990       0
# 9                     몰스킨 피너츠 데일리 2018 코랄오렌지 라지 55532    9900       0
# 10                      몰스킨 2018 / 위클리 / 블랙 소프트 / 라지L   14000       0
# 11                  낙타문구/몰스킨 2018 / 위클리 / 블랙 하드 / 포켓P   10500       0
# 12                      [한정판]몰스킨 슈퍼마리오 하드 룰드P 게임보이 그린   25540       0
# 13                      [한정판]몰스킨 슈퍼마리오 하드 룰드P 게임보이 그린   25270       0
# 14  8862936230 Moleskine Passion Journal - Gardeni...   38000       0
# 15                           몰스킨 스타벅스 2017 플래너 데일리 핑크   17000   36400
# 16               KM 몰스킨 볼란트 룰드 노트북 소프트커버 포켓 Moleskine   12600       0
# 17                               몰스킨 보이저 트래블 룰드 커피브라운   32761       0
# 18                           몰스킨 몰스킨 보이저 트래블 룰드 커피브라운   32070       0
# 19                  몰스킨 패션저널 하드커버 라지 레스토랑(Restaurant)   36300       0
# 20         [몰스킨]  Two-go 플레인+ 룰드 노트북 하드커버 미디엄/크랜베리 레드   27500       0
# 21  [핫딜 바이]Moleskine Extra Large Professional Hard...   56300       0
# 22                               몰스킨 보이저 트래블 룰드 커피브라운   33760       0
# 23                          [몰스킨]몰스킨 보이저 트래블 룰드 커피브라운   36300       0
# 24  3978425-MOLESKINE MOLESKINE CLASSIC DEVICE BAG...  165000       0
# 25                                보이저 트래블 룰드/커피브라운 노트   36300       0
# 26                몰스킨 한정판  몰스킨 노트 아톰 하드커버 룰드 라지 다크그레이   34990       0
# 27                        클래식노트 룰드(레드 하드 L Moleskine)   24920       0
# 28               클래식노트 룰드(레드 하드 L Moleskine)/fiu93334   23100       0
# 29                클래식노트 룰드 블랙 하드 L Moleskine/hre80444   22840       0
# ..                                                ...     ...     ...
# 70              몰스킨 몰스킨 패션저널 하드커버 라지 레스토랑(Restaurant)   32070       0
# 71                             TWO-GO 노트/크랜베리 레드 M 노트   27500       0
# 72                  몰스킨 패션저널 하드커버 라지 레스토랑(Restaurant)   33760       0
# 73              [몰스킨][한정판] 몰스킨 노트 아톰 하드커버 룰드 라지 다크그레이   39600       0
# 74  0137441-MOLESKINE MOLESKINE ID DEVICE BAG HORI...  173000       0
# 75                      [한정판]몰스킨 슈퍼마리오 하드 룰드P 게임보이 그린   24210       0
# 76                  몰스킨 2018 / 위클리(세로형) / 블랙 하드 / 포켓P   10500       0
# 77  [추가 5% 캐시백][Hmall]몰스킨 (현대Hmall)  정품 무료각인  몰스킨/...   35640       0
# 78                         [한정판] 스타워즈 블랙 룰드 노트북 하드-라지   36190       0
# 79  [핫딜 바이]Moleskine Pocket Address Book (Moleskin...   40400       0
# 80                          몰스킨 [18슈퍼마리오]룰드/풀스크린 블루 L   39600       0
# 81                  몰스킨 패션저널 하드커버 라지 레스토랑(Restaurant)   32761       0
# 82                         [핫트랙스] 몰스킨 [17키스해링]룰드/블랙 L   37620       0
# 83                  몰스킨 패션저널 하드커버 라지 레스토랑(Restaurant)   32416       0
# 84              몰스킨 [한정판] 몰스킨 노트 아톰 하드커버 룰드 라지 라이트그레이   34980       0
# 85                               [18아톰]룰드/라이트그레이 L 노트   39600       0
# 86                   [한정판] 몰스킨 노트 아톰 하드커버 룰드 라지 다크그레이   36830       0
# 87                     [몰스킨]몰스킨 메신저백 클래식 레더 컬렉션 슬림 블랙  272600       0
# 88              @@정품 무료각인@@[몰스킨/한정판]닥터수스 그린치-룰드-레드/라지   32440       0
# 89             낙타문구/몰스킨 2018 / 위클리(세로형) / 블랙 하드 / 포켓P   10500       0
# 90                       몰스킨 2018 / 위클리 / 블랙 하드 / 포켓P   10500       0
# 91                        한정판 몰스킨 노트 노마드 컬렉션 룰드 라지 블루   34122       0
# 92  [카드 5% 할인][신세계백화점](GAZESHOP) (신세계센텀점)몰스킨 페이퍼 태...   55840       0
# 93  [핫딜 바이]2018 Moleskine Pocket Weekly Notebook D...   45500       0
# 94                        몰스킨 [18슈퍼마리오]룰드/마리오인모션 블랙 L   39600       0
# 95                   [한정판] 몰스킨 노트 아톰 하드커버 룰드 라지 다크그레이   35739       0
# 96                  [한정판] 몰스킨 노트 아톰 하드커버 룰드 라지 라이트그레이   35363       0
# 97               몰스킨 [한정판] 몰스킨 노트 아톰 하드커버 룰드 라지 다크그레이   34980       0
# 98                  [한정판] 몰스킨 노트 아톰 하드커버 룰드 라지 라이트그레이   35739       0
# 99                   [한정판] 몰스킨 노트 아톰 하드커버 룰드 라지 다크그레이   35363       0
#
#                                                  link
# 0   http://search.shopping.naver.com/gate.nhn?id=7...
# 1   http://search.shopping.naver.com/gate.nhn?id=1...
# 2   http://search.shopping.naver.com/gate.nhn?id=1...
# 3   http://search.shopping.naver.com/gate.nhn?id=1...
# 4   http://search.shopping.naver.com/gate.nhn?id=1...
# 5   http://search.shopping.naver.com/gate.nhn?id=1...
# 6   http://search.shopping.naver.com/gate.nhn?id=1...
# 7   http://search.shopping.naver.com/gate.nhn?id=1...
# 8   http://search.shopping.naver.com/gate.nhn?id=1...
# 9   http://search.shopping.naver.com/gate.nhn?id=8...
# 10  http://search.shopping.naver.com/gate.nhn?id=1...
# 11  http://search.shopping.naver.com/gate.nhn?id=1...
# 12  http://search.shopping.naver.com/gate.nhn?id=1...
# 13  http://search.shopping.naver.com/gate.nhn?id=1...
# 14  http://search.shopping.naver.com/gate.nhn?id=1...
# 15  http://search.shopping.naver.com/gate.nhn?id=1...
# 16  http://search.shopping.naver.com/gate.nhn?id=1...
# 17  http://search.shopping.naver.com/gate.nhn?id=1...
# 18  http://search.shopping.naver.com/gate.nhn?id=1...
# 19  http://search.shopping.naver.com/gate.nhn?id=1...
# 20  http://search.shopping.naver.com/gate.nhn?id=1...
# 21  http://search.shopping.naver.com/gate.nhn?id=1...
# 22  http://search.shopping.naver.com/gate.nhn?id=1...
# 23  http://search.shopping.naver.com/gate.nhn?id=1...
# 24  http://search.shopping.naver.com/gate.nhn?id=1...
# 25  http://search.shopping.naver.com/gate.nhn?id=1...
# 26  http://search.shopping.naver.com/gate.nhn?id=1...
# 27  http://search.shopping.naver.com/gate.nhn?id=1...
# 28  http://search.shopping.naver.com/gate.nhn?id=1...
# 29  http://search.shopping.naver.com/gate.nhn?id=1...
# ..                                                ...
# 70  http://search.shopping.naver.com/gate.nhn?id=1...
# 71  http://search.shopping.naver.com/gate.nhn?id=1...
# 72  http://search.shopping.naver.com/gate.nhn?id=1...
# 73  http://search.shopping.naver.com/gate.nhn?id=1...
# 74  http://search.shopping.naver.com/gate.nhn?id=1...
# 75  http://search.shopping.naver.com/gate.nhn?id=1...
# 76  http://search.shopping.naver.com/gate.nhn?id=1...
# 77  http://search.shopping.naver.com/gate.nhn?id=1...
# 78  http://search.shopping.naver.com/gate.nhn?id=1...
# 79  http://search.shopping.naver.com/gate.nhn?id=1...
# 80  http://search.shopping.naver.com/gate.nhn?id=1...
# 81  http://search.shopping.naver.com/gate.nhn?id=1...
# 82  http://search.shopping.naver.com/gate.nhn?id=1...
# 83  http://search.shopping.naver.com/gate.nhn?id=1...
# 84  http://search.shopping.naver.com/gate.nhn?id=1...
# 85  http://search.shopping.naver.com/gate.nhn?id=1...
# 86  http://search.shopping.naver.com/gate.nhn?id=1...
# 87  http://search.shopping.naver.com/gate.nhn?id=1...
# 88  http://search.shopping.naver.com/gate.nhn?id=1...
# 89  http://search.shopping.naver.com/gate.nhn?id=1...
# 90  http://search.shopping.naver.com/gate.nhn?id=1...
# 91  http://search.shopping.naver.com/gate.nhn?id=1...
# 92  http://search.shopping.naver.com/gate.nhn?id=1...
# 93  http://search.shopping.naver.com/gate.nhn?id=1...
# 94  http://search.shopping.naver.com/gate.nhn?id=1...
# 95  http://search.shopping.naver.com/gate.nhn?id=1...
# 96  http://search.shopping.naver.com/gate.nhn?id=1...
# 97  http://search.shopping.naver.com/gate.nhn?id=1...
# 98  http://search.shopping.naver.com/gate.nhn?id=1...
# 99  http://search.shopping.naver.com/gate.nhn?id=1...
#
# [100 rows x 4 columns]

# %%
#가격 결과 float형으로 변환
result_mol['lprice'] = result_mol['lprice'].astype('float')
result_mol['hprice'] = result_mol['hprice'].astype('float')
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
# title     100 non-null object
# lprice    100 non-null float64
# hprice    100 non-null float64
# link      100 non-null object
# dtypes: float64(2), object(2)
# memory usage: 3.2+ KB

# %%
# writer에 대한 정보는 강의자료 페이지에 사이트 참고
# 위의 100개 결과를 excelwriter 함수를 이용하여 엑셀 형식으로 저장
writer = pd.ExcelWriter("../source_code/05_molskin_diary_in_naver_shop.xlsx", engine = 'xlsxwriter')
# 저장위치, 파일 명, 파일 형식 지정
result_mol.to_excel(writer, sheet_name = 'Sheet1')
# 위의 결과를 writer에 따라 excel로 저장하고 sheet 이름을 Sheet1로 함.

workbook = writer.book
worksheet = writer.sheets['Sheet1']
worksheet.set_column('A:A', 4) # A열 전체 넒이 4
worksheet.set_column('B:B', 60) # B열의 넓이 60
worksheet.set_column('C:C', 10)
worksheet.set_column('D:D', 10)
worksheet.set_column('E:E', 50)

worksheet.conditional_format('C2:C101', {'type' : '3_color_scale'})
# C열은 녹,주,황색으로 수치의 크기 표현
writer.save()

# %%
#클로바 얼굴 인식, 닮은 연예인
import requests
client_id = "kUMekrHWTsTF09Meg3Sj"
client_secret = "DYchAGoQGY"
url = 'https://openapi.naver.com/v1/vision/celebrity'
files = {'image':open('../source_code/jiseung1.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, "X-Naver-Client-Secret" : client_secret }

response = requests.post(url, files=files, headers=headers)
# url주소에 file로 저장한 이미지와 인증 정보를 담아 API호출
rescode = response.status_code # 올바른 요청 결과 코드 rescode로 저장
if(rescode==200): # 200(올바른 요청 결과)
    print(response.text) # 요청 결과 출력
else:
    print('Error code'+ rescode) # 올바르지 않은 결과 error코드 출력
# Out:
# {"info":{"size":{"width":653,"height":890},"faceCount":1},"faces":[{"celebrity":{"value":"방중현","confidence":0.209463}}]}

# %%
# 클로바 얼굴인식, 연령, 성별, 기분 정보 추정
url = 'https://openapi.naver.com/v1/vision/face'
files = {'image':open('../source_code/jiseung1.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, "X-Naver-Client-Secret" : client_secret }
response = requests.post(url, files=files, headers=headers)
rescode = response.status_code
if(rescode==200):
    print(response.text)
else:
    print('Error code'+ rescode)
# Out:
# {"info":{"size":{"width":653,"height":890},"faceCount":1},"faces":[{"roi":{"x":257,"y":137,"width":353,"height":353},"landmark":{"leftEye":{"x":369,"y":211},"rightEye":{"x":513,"y":210},"nose":{"x":439,"y":309},"leftMouth":{"x":328,"y":354},"rightMouth":{"x":484,"y":385}},"gender":{"value":"male","confidence":0.677208},"age":{"value":"24~28","confidence":0.255111},"emotion":{"value":"smile","confidence":0.907053},"pose":{"value":"frontal_face","confidence":0.998425}}]}

# %%
# 사진에 박스 넣기
# 사진에 축정보 입력 위해 plt모듈 호출
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches
import numpy as np
# %matplotlib inline

img = mpimg.imread('../source_code/face_detection_test_IU.jpg')
imgplot = plt.imshow(img)

# %%
import json
# 사진에 대한 얼굴인식 정보 json형태로 변수 저장
detection_result = json.loads(response.text)
detection_result
# Out:
# {'faces': [{'age': {'confidence': 0.374036, 'value': '12~16'},
#    'emotion': {'confidence': 0.99803, 'value': 'neutral'},
#    'gender': {'confidence': 0.993843, 'value': 'female'},
#    'landmark': {'leftEye': {'x': 320, 'y': 325},
#     'leftMouth': {'x': 393, 'y': 620},
#     'nose': {'x': 460, 'y': 454},
#     'rightEye': {'x': 575, 'y': 287},
#     'rightMouth': {'x': 572, 'y': 594}},
#    'pose': {'confidence': 0.999622, 'value': 'frontal_face'},
#    'roi': {'height': 517, 'width': 517, 'x': 196, 'y': 193}}],
#  'info': {'faceCount': 1, 'size': {'height': 836, 'width': 914}}}

# %%
#'face' key값 내 key 정보 출력
detection_summary = detection_result['faces'][0]
detection_summary.keys()
# Out:
# dict_keys(['gender', 'landmark', 'age', 'roi', 'pose', 'emotion'])

# %%
detection_summary['roi']
# 'roi' key는 얼굴 위치 좌표
# dict형은 순서가 없으므로 [roi][height] value하나씩 저장 필요함.
# Out:
# {'height': 517, 'width': 517, 'x': 196, 'y': 193}

# %%
# 얼굴위치 좌표 저장
h,w,x,y = detection_summary['roi'].values()
h,w,x,y
# Out:
# (193, 517, 517, 196)

# %%
gender, gen_confidence = detection_summary['gender'].values()
gender, gen_confidence
# Out:
# ('female', 0.993843)

# %%
# 얼굴좌표, 성별 정보, 감성정보, 나이 정보 저장
w,h,x,y = detection_summary['roi'].values()
gender, gen_confidence = detection_summary['gender'].values()
emotion, emotion_confidence = detection_summary['emotion'].values()
age, age_confidence = detection_summary['age'].values()

# %%
detection_summary['roi'].values()
# Out:
# dict_values([193, 517, 517, 196])

# %%
# 사진에 박스 그리기
fig, ax = plt.subplots(figsize=(10,10)) 
# 축 정보를 갖는 subplot 그리기
ax.imshow(img) 
# 이미지 보기
# 얼굴 인식 좌표 정보 위치에 박스 그리기
rect_face = patches.Rectangle((x,y),w,h,
                             linewidth = 5,
                             edgecolor = 'r',
                             facecolor = 'none')
ax.add_patch(rect_face) # 박스 넣기
# 사진에 들어갈 주석
annotation = gender + ' : '+ str(gen_confidence) + \
'\n'+emotion+ ' : ' +str(emotion_confidence)+\
'\n'+age+' : '+str(age_confidence)
plt.figtext(0.15, 0.17, annotation, wrap = True, fontsize=17, color = 'white') # 주석 내용 서식
plt. show()

# %%
def plotSinwave(**kwargs):
    """
    plot sine wave
    y = a sin(2 pi f t) + b
    """
    
    endTime, sampleTime = kwargs.get('endTime',1), kwargs.get('sampleTime',0.01)
    amp, freq, bias = kwargs.get('amp',1), kwargs.get('freq',1), kwargs.get('bias',0)
    figsize = kwargs.get('figsize',(12,6))
    
    time = np.arange(0, endTime, sampleTime)
    result = amp*np.sin(2*np.pi*freq*time) + bias
    
        
    plt.figure(figsize =(12,6))
    plt.plot(time, result); plt.grid(True)
    plt.xlabel('time'); plt.ylabel('sin')
    plt.title(str(amp)+'*sin(2*pi*'+str(freq)+'*t)+'+str(bias))
    plt.show()

# %%
import pandas as pd
import numpy as np

def creat_test_data():
    time = np.linspace(0,1,365*2)
    result = np.sin(2*np.pi*12*time)
    ds = pd.date_range('2017-01-01', periods = 365*2, freq = "D")
    return pd.DataFrame({'ds':ds, 'y':result})

# %%
df = creat_test_data()
df
# Out:
#             ds             y
# 0   2017-01-01  0.000000e+00
# 1   2017-01-02  1.032426e-01
# 2   2017-01-03  2.053818e-01
# 3   2017-01-04  3.053260e-01
# 4   2017-01-05  4.020070e-01
# 5   2017-01-06  4.943914e-01
# 6   2017-01-07  5.814921e-01
# 7   2017-01-08  6.623779e-01
# 8   2017-01-09  7.361846e-01
# 9   2017-01-10  8.021232e-01
# 10  2017-01-11  8.594890e-01
# 11  2017-01-12  9.076690e-01
# 12  2017-01-13  9.461482e-01
# 13  2017-01-14  9.745153e-01
# 14  2017-01-15  9.924672e-01
# 15  2017-01-16  9.998120e-01
# 16  2017-01-17  9.964712e-01
# 17  2017-01-18  9.824805e-01
# 18  2017-01-19  9.579895e-01
# 19  2017-01-20  9.232599e-01
# 20  2017-01-21  8.786628e-01
# 21  2017-01-22  8.246750e-01
# 22  2017-01-23  7.618734e-01
# 23  2017-01-24  6.909291e-01
# 24  2017-01-25  6.126005e-01
# 25  2017-01-26  5.277247e-01
# 26  2017-01-27  4.372088e-01
# 27  2017-01-28  3.420201e-01
# 28  2017-01-29  2.431761e-01
# 29  2017-01-30  1.417331e-01
# ..         ...           ...
# 700 2018-12-02 -1.417331e-01
# 701 2018-12-03 -2.431761e-01
# 702 2018-12-04 -3.420201e-01
# 703 2018-12-05 -4.372088e-01
# 704 2018-12-06 -5.277247e-01
# 705 2018-12-07 -6.126005e-01
# 706 2018-12-08 -6.909291e-01
# 707 2018-12-09 -7.618734e-01
# 708 2018-12-10 -8.246750e-01
# 709 2018-12-11 -8.786628e-01
# 710 2018-12-12 -9.232599e-01
# 711 2018-12-13 -9.579895e-01
# 712 2018-12-14 -9.824805e-01
# 713 2018-12-15 -9.964712e-01
# 714 2018-12-16 -9.998120e-01
# 715 2018-12-17 -9.924672e-01
# 716 2018-12-18 -9.745153e-01
# 717 2018-12-19 -9.461482e-01
# 718 2018-12-20 -9.076690e-01
# 719 2018-12-21 -8.594890e-01
# 720 2018-12-22 -8.021232e-01
# 721 2018-12-23 -7.361846e-01
# 722 2018-12-24 -6.623779e-01
# 723 2018-12-25 -5.814921e-01
# 724 2018-12-26 -4.943914e-01
# 725 2018-12-27 -4.020070e-01
# 726 2018-12-28 -3.053260e-01
# 727 2018-12-29 -2.053818e-01
# 728 2018-12-30 -1.032426e-01
# 729 2018-12-31 -2.939152e-15
#
# [730 rows x 2 columns]

# %%
df.plot(x='ds', y = 'y', figsize=(12,6));

# %%
from fbprophet import Prophet
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-f503e9c6cf11> in <module>()
# ----> 1 from fbprophet import Prophet
#
# ~\Anaconda3\lib\site-packages\fbprophet\__init__.py in <module>()
#       6 # of patent rights can be found in the PATENTS file in the same directory.
#       7
# ----> 8 from fbprophet.forecaster import Prophet
#       9
#      10 __version__ = '0.2.1'
#
# ~\Anaconda3\lib\site-packages\fbprophet\forecaster.py in <module>()
#      26
#      27 # fb-block 1 start
# ---> 28 from fbprophet.models import prophet_stan_models
#      29 # fb-block 1 end
#      30
#
# ~\Anaconda3\lib\site-packages\fbprophet\models.py in <module>()
#      33
#      34 prophet_stan_models = {
# ---> 35     'linear': get_prophet_stan_model('linear'),
#      36     'logistic': get_prophet_stan_model('logistic'),
#      37 }
#
# ~\Anaconda3\lib\site-packages\fbprophet\models.py in get_prophet_stan_model(model)
#      29     # fb-block 4 end
#      30     with open(model_file, 'rb') as f:
# ---> 31         return pickle.load(f)
#      32
#      33
#
# ~\Anaconda3\lib\site-packages\pystan\__init__.py in <module>()
#       7 import logging
#       8
# ----> 9 from pystan.api import stanc, stan
#      10 from pystan.misc import read_rdump, stan_rdump, stansummary
#      11 from pystan.model import StanModel
#
# ~\Anaconda3\lib\site-packages\pystan\api.py in <module>()
#      13 import pystan._api  # stanc wrapper
#      14 from pystan._compat import string_types, PY2
# ---> 15 from pystan.model import StanModel
#      16
#      17 logger = logging.getLogger('pystan')
#
# ~\Anaconda3\lib\site-packages\pystan\model.py in <module>()
#      30
#      31 import Cython
# ---> 32 from Cython.Build.Inline import _get_build_extension
#      33 from Cython.Build.Dependencies import cythonize
#      34
#
# ~\Anaconda3\lib\site-packages\Cython\Build\Inline.py in <module>()
#      15 from ..Compiler.Main import Context, CompilationOptions, default_options
#      16
# ---> 17 from ..Compiler.ParseTreeTransforms import (CythonTransform,
#      18         SkipDeclarations, AnalyseDeclarationsTransform, EnvTransform)
#      19 from ..Compiler.TreeFragment import parse_from_strings
#
# ~\Anaconda3\lib\site-packages\Cython\Compiler\ParseTreeTransforms.py in <module>()
#      21 from .Visitor import CythonTransform, EnvTransform, ScopeTrackingTransform
#      22 from .UtilNodes import LetNode, LetRefNode
# ---> 23 from .TreeFragment import TreeFragment
#      24 from .StringEncoding import EncodedString, _unicode
#      25 from .Errors import error, warning, CompileError, InternalError
#
# ~\Anaconda3\lib\site-packages\Cython\Compiler\TreeFragment.py in <module>()
#      19 from .ExprNodes import NameNode
#      20 from .StringEncoding import _unicode
# ---> 21 from . import Parsing
#      22 from . import Main
#      23 from . import UtilNodes
#
# ~\Anaconda3\lib\site-packages\Cython\Compiler\Parsing.py in init Cython.Compiler.Parsing()
#      28 from . import StringEncoding
#      29 from .StringEncoding import EncodedString, bytes_literal, _unicode, _bytes
# ---> 30 from .ModuleNode import ModuleNode
#      31 from .Errors import error, warning
#      32 from .. import Utils
#
# ~\Anaconda3\lib\site-packages\Cython\Compiler\ModuleNode.py in <module>()
#    3112 """, impl="", proto_block='utility_code_proto_before_types')
#    3113
# -> 3114 capsule_utility_code = UtilityCode.load("Capsule")
#
# ~\Anaconda3\lib\site-packages\Cython\Compiler\Code.cp35-win_amd64.pyd in Cython.Compiler.Code.UtilityCodeBase.load()
#
# ValueError: More than one filename match found for utility code Capsule
