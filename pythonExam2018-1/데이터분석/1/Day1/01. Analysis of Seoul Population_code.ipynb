# %% [markdown]
# # 1주차 : 서울시 인구 현황 분석

# %% [markdown]
# * 데이터 : http://stat.seoul.go.kr/jsp3/stat.db.jsp 에서 구별 인구현황을 **숫자형식 엑셀**로 다운로드

# %% [markdown]
# # Raw Data 정리하기

# %%
import pandas as pd

# %% [markdown]
# pd.read_excel('../data/01_Population_Seoul.xls')

# %%
pd.read_excel('pythonExam2018-1/exam/data/01_Population_Seoul.xls', header=2)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>기간</th>
#       <th>자치구</th>
#       <th>세대</th>
#       <th>계</th>
#       <th>남자</th>
#       <th>여자</th>
#       <th>계.1</th>
#       <th>남자.1</th>
#       <th>여자.1</th>
#       <th>계.2</th>
#       <th>남자.2</th>
#       <th>여자.2</th>
#       <th>세대당인구</th>
#       <th>65세이상고령자</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2018.2/4</td>
#       <td>합계</td>
#       <td>4241547</td>
#       <td>10089517</td>
#       <td>4935944</td>
#       <td>5153573</td>
#       <td>9814049</td>
#       <td>4802769</td>
#       <td>5011280</td>
#       <td>275468</td>
# ...

# %%
pd.read_excel('pythonExam2018-1/exam//data/01_Population_Seoul.xls', header=2, usecols="B,D:N")
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>자치구</th>
#       <th>계</th>
#       <th>남자</th>
#       <th>여자</th>
#       <th>계.1</th>
#       <th>남자.1</th>
#       <th>여자.1</th>
#       <th>계.2</th>
#       <th>남자.2</th>
#       <th>여자.2</th>
#       <th>세대당인구</th>
#       <th>65세이상고령자</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>합계</td>
#       <td>10089517</td>
#       <td>4935944</td>
#       <td>5153573</td>
#       <td>9814049</td>
#       <td>4802769</td>
#       <td>5011280</td>
#       <td>275468</td>
#       <td>133175</td>
#       <td>142293</td>
#       <td>2.31</td>
#       <td>1393671</td>
#     </tr>
# ...

# %%
pd.read_excel('pythonExam2018-1/exam/data/01_Population_Seoul.xls', 
              header=2, usecols="B,D:N", skipfooter=1)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>자치구</th>
#       <th>계</th>
#       <th>남자</th>
#       <th>여자</th>
#       <th>계.1</th>
#       <th>남자.1</th>
#       <th>여자.1</th>
#       <th>계.2</th>
#       <th>남자.2</th>
#       <th>여자.2</th>
#       <th>세대당인구</th>
#       <th>65세이상고령자</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>합계</td>
#       <td>10089517</td>
#       <td>4935944</td>
#       <td>5153573</td>
#       <td>9814049</td>
#       <td>4802769</td>
#       <td>5011280</td>
#       <td>275468</td>
#       <td>133175</td>
#       <td>142293</td>
#       <td>2.31</td>
#       <td>1393671</td>
#     </tr>
# ...

# %%
col_names = ['구','인구수','남성','여성','내국인','남성내국인','여성내국인',
             '외국인','남성외국인','여성외국인','세대당인구','고령자']
pd.read_excel('pythonExam2018-1/exam/data/01_Population_Seoul.xls', 
              header=2, usecols="B,D:N", names=col_names, skipfooter=1)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>구</th>
#       <th>인구수</th>
#       <th>남성</th>
#       <th>여성</th>
#       <th>내국인</th>
#       <th>남성내국인</th>
#       <th>여성내국인</th>
#       <th>외국인</th>
#       <th>남성외국인</th>
#       <th>여성외국인</th>
#       <th>세대당인구</th>
#       <th>고령자</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>합계</td>
#       <td>10089517</td>
#       <td>4935944</td>
#       <td>5153573</td>
#       <td>9814049</td>
#       <td>4802769</td>
#       <td>5011280</td>
#       <td>275468</td>
#       <td>133175</td>
#       <td>142293</td>
#       <td>2.31</td>
#       <td>1393671</td>
#     </tr>
# ...

# %%
col_names = ['구','인구수','남성','여성','내국인','남성내국인','여성내국인',
             '외국인','남성외국인','여성외국인','세대당인구','고령자']
raw_data = pd.read_excel('pythonExam2018-1/exam/data/01_Population_Seoul.xls', 
                         header=2, usecols="B,D:N", names=col_names, skipfooter=1)

# %%
raw_data['구'].unique()
# Out:
# array(['합계', '종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구',
#        '강북구', '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구',
#        '금천구', '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구'], dtype=object)

# %%
raw_data.drop(0, inplace=True)
raw_data
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>구</th>
#       <th>인구수</th>
#       <th>남성</th>
#       <th>여성</th>
#       <th>내국인</th>
#       <th>남성내국인</th>
#       <th>여성내국인</th>
#       <th>외국인</th>
#       <th>남성외국인</th>
#       <th>여성외국인</th>
#       <th>세대당인구</th>
#       <th>고령자</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>종로구</td>
#       <td>163569</td>
#       <td>79522</td>
#       <td>84047</td>
#       <td>153780</td>
#       <td>75247</td>
#       <td>78533</td>
#       <td>9789</td>
#       <td>4275</td>
#       <td>5514</td>
#       <td>2.09</td>
#       <td>26512</td>
#     </tr>
#     <tr>
# ...

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24 entries, 1 to 24
# Data columns (total 12 columns):
# 구        24 non-null object
# 인구수      24 non-null int64
# 남성       24 non-null int64
# 여성       24 non-null int64
# 내국인      24 non-null int64
# 남성내국인    24 non-null int64
# 여성내국인    24 non-null int64
# 외국인      24 non-null int64
# 남성외국인    24 non-null int64
# 여성외국인    24 non-null int64
# 세대당인구    24 non-null float64
# 고령자      24 non-null int64
# dtypes: float64(1), int64(10), object(1)
# memory usage: 2.4+ KB

# %%
raw_data.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>인구수</th>
#       <th>남성</th>
#       <th>여성</th>
#       <th>내국인</th>
#       <th>남성내국인</th>
#       <th>여성내국인</th>
#       <th>외국인</th>
#       <th>남성외국인</th>
#       <th>여성외국인</th>
#       <th>세대당인구</th>
#       <th>고령자</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>24.00000</td>
#       <td>24.000000</td>
#       <td>24.000000</td>
#       <td>24.000000</td>
#       <td>24.000000</td>
#       <td>24.000000</td>
#       <td>24.000000</td>
#       <td>24.000000</td>
#       <td>24.000000</td>
#       <td>24.000000</td>
#       <td>24.000000</td>
#     </tr>
#     <tr>
# ...

# %%
## Pandas 기초

* https://pandas.pydata.org/pandas-docs/stable/10min.html

# %% [markdown]
# import numpy as np
# s = pd.Series([1,3,5,np.nan,6,8])
# s

# %%
import numpy as np
dates = pd.date_range('20130101', periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=['A','B','C','D'])
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>0.803842</td>
#       <td>-0.117877</td>
#       <td>-0.842992</td>
#       <td>0.199169</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>0.672485</td>
#       <td>-0.033409</td>
#       <td>0.770891</td>
#       <td>1.539067</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>1.961334</td>
#       <td>1.408339</td>
#       <td>0.395291</td>
#       <td>0.209340</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
# ...

# %%
data = {'A' : 1.,
        'B' : pd.Timestamp('20130102'),
        'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
        'D' : np.array([3] * 4,dtype='int32'),
        'E' : pd.Categorical(["test","train","test","train"]),
        'F' : 'foo' }
data
# Out:
# {'A': 1.0, 'B': Timestamp('2013-01-02 00:00:00'), 'C': 0    1.0
#  1    1.0
#  2    1.0
#  3    1.0
#  dtype: float32, 'D': array([3, 3, 3, 3], dtype=int32), 'E': [test, train, test, train]
#  Categories (2, object): [test, train], 'F': 'foo'}

# %%
df2 = pd.DataFrame(data)
df2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#       <th>F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>2013-01-02</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>test</td>
#       <td>foo</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>2013-01-02</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>train</td>
#       <td>foo</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.0</td>
#       <td>2013-01-02</td>
#       <td>1.0</td>
#       <td>3</td>
# ...

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>0.803842</td>
#       <td>-0.117877</td>
#       <td>-0.842992</td>
#       <td>0.199169</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>0.672485</td>
#       <td>-0.033409</td>
#       <td>0.770891</td>
#       <td>1.539067</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>1.961334</td>
#       <td>1.408339</td>
#       <td>0.395291</td>
#       <td>0.209340</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
# ...

# %%
df.tail()
# Out:
#                    A         B         C         D
# 2013-01-02  1.013746 -0.358602 -2.013711  1.664339
# 2013-01-03 -0.679952  1.485216 -1.392012  1.291496
# 2013-01-04  0.303551  1.530421  0.339824 -1.514466
# 2013-01-05 -2.391673  2.151715 -0.215974  1.326231
# 2013-01-06 -1.842101  1.158619 -0.924924 -1.776429

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[-0.27795523, -0.04509365,  1.32208008,  0.35170079],
#        [ 1.0137461 , -0.35860245, -2.01371093,  1.66433869],
#        [-0.6799518 ,  1.48521646, -1.39201245,  1.29149587],
#        [ 0.30355057,  1.53042113,  0.33982379, -1.51446609],
#        [-2.39167347,  2.15171517, -0.21597352,  1.32623093],
#        [-1.84210141,  1.15861914, -0.92492441, -1.77642912]])

# %%
df.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>6.000000</td>
#       <td>6.000000</td>
#       <td>6.000000</td>
#       <td>6.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>0.426892</td>
#       <td>0.545619</td>
#       <td>0.006808</td>
#       <td>0.053734</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>1.018483</td>
#       <td>0.847958</td>
#       <td>1.166666</td>
#       <td>1.025099</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>-1.063323</td>
# ...

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>0.803842</td>
#       <td>-0.117877</td>
#       <td>-0.842992</td>
#       <td>0.199169</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>0.672485</td>
#       <td>-0.033409</td>
#       <td>0.770891</td>
#       <td>1.539067</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>1.961334</td>
#       <td>1.408339</td>
#       <td>0.395291</td>
#       <td>0.209340</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
# ...

# %%
df.T
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>2013-01-01 00:00:00</th>
#       <th>2013-01-02 00:00:00</th>
#       <th>2013-01-03 00:00:00</th>
#       <th>2013-01-04 00:00:00</th>
#       <th>2013-01-05 00:00:00</th>
#       <th>2013-01-06 00:00:00</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>0.803842</td>
#       <td>0.672485</td>
#       <td>1.961334</td>
#       <td>-1.063323</td>
#       <td>0.398952</td>
#       <td>-0.211937</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>-0.117877</td>
#       <td>-0.033409</td>
#       <td>1.408339</td>
#       <td>1.727343</td>
#       <td>-0.278052</td>
# ...

# %%
df.sort_index(axis=1, ascending=False)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>D</th>
#       <th>C</th>
#       <th>B</th>
#       <th>A</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>0.199169</td>
#       <td>-0.842992</td>
#       <td>-0.117877</td>
#       <td>0.803842</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>1.539067</td>
#       <td>0.770891</td>
#       <td>-0.033409</td>
#       <td>0.672485</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>0.209340</td>
#       <td>0.395291</td>
#       <td>1.408339</td>
#       <td>1.961334</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
# ...

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2013-01-02  1.013746 -0.358602 -2.013711  1.664339
# 2013-01-01 -0.277955 -0.045094  1.322080  0.351701
# 2013-01-06 -1.842101  1.158619 -0.924924 -1.776429
# 2013-01-03 -0.679952  1.485216 -1.392012  1.291496
# 2013-01-04  0.303551  1.530421  0.339824 -1.514466
# 2013-01-05 -2.391673  2.151715 -0.215974  1.326231

# %%
df.sort_values(by='B', ascending=False)
# Out:
#                    A         B         C         D
# 2013-01-05 -2.391673  2.151715 -0.215974  1.326231
# 2013-01-04  0.303551  1.530421  0.339824 -1.514466
# 2013-01-03 -0.679952  1.485216 -1.392012  1.291496
# 2013-01-06 -1.842101  1.158619 -0.924924 -1.776429
# 2013-01-01 -0.277955 -0.045094  1.322080  0.351701
# 2013-01-02  1.013746 -0.358602 -2.013711  1.664339

# %%
df['A']
# Out:
# 2013-01-01    0.803842
# 2013-01-02    0.672485
# 2013-01-03    1.961334
# 2013-01-04   -1.063323
# 2013-01-05    0.398952
# 2013-01-06   -0.211937
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>0.803842</td>
#       <td>-0.117877</td>
#       <td>-0.842992</td>
#       <td>0.199169</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>0.672485</td>
#       <td>-0.033409</td>
#       <td>0.770891</td>
#       <td>1.539067</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>1.961334</td>
#       <td>1.408339</td>
#       <td>0.395291</td>
#       <td>0.209340</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.loc[dates[0]]
# Out:
# A   -0.277955
# B   -0.045094
# C    1.322080
# D    0.351701
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:,['A','B']]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>0.803842</td>
#       <td>-0.117877</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>0.672485</td>
#       <td>-0.033409</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>1.961334</td>
#       <td>1.408339</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
#       <td>-1.063323</td>
#       <td>1.727343</td>
#     </tr>
#     <tr>
#       <th>2013-01-05</th>
#       <td>0.398952</td>
#       <td>-0.278052</td>
#     </tr>
#     <tr>
# ...

# %%
df.loc['20130102':'20130104',['A','B']]
# Out:
#                    A         B
# 2013-01-02  1.013746 -0.358602
# 2013-01-03 -0.679952  1.485216
# 2013-01-04  0.303551  1.530421

# %%
df.loc['20130102',['A','B']]
# Out:
# A    1.013746
# B   -0.358602
# Name: 2013-01-02 00:00:00, dtype: float64

# %%
df.loc[dates[0],'A']
# Out:
# -0.2779552293178475

# %%
df.iloc[3]
# Out:
# A    0.303551
# B    1.530421
# C    0.339824
# D   -1.514466
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5,0:2]
# Out:
#                    A         B
# 2013-01-04  0.303551  1.530421
# 2013-01-05 -2.391673  2.151715

# %%
df.iloc[[1,2,4],[0,2]]
# Out:
#                    A         C
# 2013-01-02  1.013746 -2.013711
# 2013-01-03 -0.679952 -1.392012
# 2013-01-05 -2.391673 -0.215974

# %%
df.iloc[1:3,:]
# Out:
#                    A         B         C         D
# 2013-01-02  1.013746 -0.358602 -2.013711  1.664339
# 2013-01-03 -0.679952  1.485216 -1.392012  1.291496

# %%
df.iloc[:,1:3]
# Out:
#                    B         C
# 2013-01-01 -0.045094  1.322080
# 2013-01-02 -0.358602 -2.013711
# 2013-01-03  1.485216 -1.392012
# 2013-01-04  1.530421  0.339824
# 2013-01-05  2.151715 -0.215974
# 2013-01-06  1.158619 -0.924924

# %%
df.iloc[1,1]
# Out:
# -0.3586024507544445

# %%
df[df['A'] > 0]
# Out:
#                    A         B         C         D
# 2013-01-02  1.013746 -0.358602 -2.013711  1.664339
# 2013-01-04  0.303551  1.530421  0.339824 -1.514466

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01       NaN       NaN  1.322080  0.351701
# 2013-01-02  1.013746       NaN       NaN  1.664339
# 2013-01-03       NaN  1.485216       NaN  1.291496
# 2013-01-04  0.303551  1.530421  0.339824       NaN
# 2013-01-05       NaN  2.151715       NaN  1.326231
# 2013-01-06       NaN  1.158619       NaN       NaN

# %%
a = [1,2,3]
b = a
b[1] = 0
b
# Out:
# [1, 0, 3]

# %%
a
# Out:
# [1, 0, 3]

# %%
c = [1,2,3]
d = c.copy()
d[1] = 0
d
# Out:
# [1, 0, 3]

# %%
c
# Out:
# [1, 2, 3]

# %%
df2 = df.copy()

# %%
df2['E'] = ['one', 'one','two','three','four','three']
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01 -0.277955 -0.045094  1.322080  0.351701    one
# 2013-01-02  1.013746 -0.358602 -2.013711  1.664339    one
# 2013-01-03 -0.679952  1.485216 -1.392012  1.291496    two
# 2013-01-04  0.303551  1.530421  0.339824 -1.514466  three
# 2013-01-05 -2.391673  2.151715 -0.215974  1.326231   four
# 2013-01-06 -1.842101  1.158619 -0.924924 -1.776429  three

# %%
data = {'a':[1,2,3,4],'b':[0,1,0.1,0.2],'sub':['1st','2nd','3rd','4th']}
data
# Out:
# {'a': [1, 2, 3, 4], 'b': [0, 1, 0.1, 0.2], 'sub': ['1st', '2nd', '3rd', '4th']}

# %%
df3 = pd.DataFrame(data)
df3
# Out:
#    a    b  sub
# 0  1  0.0  1st
# 1  2  1.0  2nd
# 2  3  0.1  3rd
# 3  4  0.2  4th

# %%
df3 = pd.DataFrame(data, columns=['sub','a','b'])
df3
# Out:
#    sub  a    b
# 0  1st  1  0.0
# 1  2nd  2  1.0
# 2  3rd  3  0.1
# 3  4th  4  0.2

# %%
df3 = df3.reindex(index=[0,2,1,3])
df3
# Out:
#    sub  a    b
# 0  1st  1  0.0
# 2  3rd  3  0.1
# 1  2nd  2  1.0
# 3  4th  4  0.2

# %%
df3['c'] = np.nan
df3
# Out:
#    sub  a    b   c
# 0  1st  1  0.0 NaN
# 2  3rd  3  0.1 NaN
# 1  2nd  2  1.0 NaN
# 3  4th  4  0.2 NaN

# %%
df3.loc[1,['c']] = 2
df3
# Out:
#    sub  a    b    c
# 0  1st  1  0.0  NaN
# 2  3rd  3  0.1  NaN
# 1  2nd  2  1.0  2.0
# 3  4th  4  0.2  NaN

# %%
df3['d']= df3['a'] + df3['b']
df3
# Out:
#    sub  a    b    c    d
# 0  1st  1  0.0  NaN  1.0
# 2  3rd  3  0.1  NaN  3.1
# 1  2nd  2  1.0  2.0  3.0
# 3  4th  4  0.2  NaN  4.2

# %%
df3.loc[4] = np.nan
df3
# Out:
#    sub    a    b    c    d
# 0  1st  1.0  0.0  NaN  1.0
# 2  3rd  3.0  0.1  NaN  3.1
# 1  2nd  2.0  1.0  2.0  3.0
# 3  4th  4.0  0.2  NaN  4.2
# 4  NaN  NaN  NaN  NaN  NaN

# %%
df3.loc[4] = ['5th','a','b','c','d']
df3
# Out:
#    sub  a    b    c    d
# 0  1st  1    0  NaN    1
# 2  3rd  3  0.1  NaN  3.1
# 1  2nd  2    1    2    3
# 3  4th  4  0.2  NaN  4.2
# 4  5th  a    b    c    d

# %% [markdown]
# ## 인구비율만들기

# %%
raw_data
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>구</th>
#       <th>인구수</th>
#       <th>남성</th>
#       <th>여성</th>
#       <th>내국인</th>
#       <th>남성내국인</th>
#       <th>여성내국인</th>
#       <th>외국인</th>
#       <th>남성외국인</th>
#       <th>여성외국인</th>
#       <th>세대당인구</th>
#       <th>고령자</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>종로구</td>
#       <td>163569</td>
#       <td>79522</td>
#       <td>84047</td>
#       <td>153780</td>
#       <td>75247</td>
#       <td>78533</td>
#       <td>9789</td>
#       <td>4275</td>
#       <td>5514</td>
#       <td>2.09</td>
#       <td>26512</td>
#     </tr>
#     <tr>
# ...

# %%
raw_data.corr()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>인구수</th>
#       <th>남성</th>
#       <th>여성</th>
#       <th>내국인</th>
#       <th>남성내국인</th>
#       <th>여성내국인</th>
#       <th>외국인</th>
#       <th>남성외국인</th>
#       <th>여성외국인</th>
#       <th>세대당인구</th>
#       <th>고령자</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>인구수</th>
#       <td>1.000000</td>
#       <td>0.998466</td>
#       <td>0.998648</td>
#       <td>0.997921</td>
#       <td>0.998256</td>
#       <td>0.995642</td>
#       <td>-0.153021</td>
#       <td>-0.127911</td>
#       <td>-0.179125</td>
#       <td>0.540802</td>
#       <td>0.939840</td>
#     </tr>
#     <tr>
# ...

# %%
raw_data['외국인비율'] = raw_data['외국인'] / raw_data['인구수']
raw_data['고령비율'] = raw_data['고령자'] / raw_data['인구수']
raw_data['여성비율'] = raw_data['여성'] / raw_data['인구수']
raw_data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>구</th>
#       <th>인구수</th>
#       <th>남성</th>
#       <th>여성</th>
#       <th>내국인</th>
#       <th>남성내국인</th>
#       <th>여성내국인</th>
#       <th>외국인</th>
#       <th>남성외국인</th>
#       <th>여성외국인</th>
#       <th>세대당인구</th>
#       <th>고령자</th>
#       <th>외국인비율</th>
#       <th>고령비율</th>
#       <th>여성비율</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>종로구</td>
#       <td>163569</td>
#       <td>79522</td>
#       <td>84047</td>
#       <td>153780</td>
#       <td>75247</td>
#       <td>78533</td>
#       <td>9789</td>
#       <td>4275</td>
#       <td>5514</td>
# ...

# %%
raw_data.sort_values(by='인구수', ascending=False)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>구</th>
#       <th>인구수</th>
#       <th>남성</th>
#       <th>여성</th>
#       <th>내국인</th>
#       <th>남성내국인</th>
#       <th>여성내국인</th>
#       <th>외국인</th>
#       <th>남성외국인</th>
#       <th>여성외국인</th>
#       <th>세대당인구</th>
#       <th>고령자</th>
#       <th>외국인비율</th>
#       <th>고령비율</th>
#       <th>여성비율</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>24</th>
#       <td>송파구</td>
#       <td>673161</td>
#       <td>327051</td>
#       <td>346110</td>
#       <td>666439</td>
#       <td>323741</td>
#       <td>342698</td>
#       <td>6722</td>
#       <td>3310</td>
#       <td>3412</td>
# ...

# %%
raw_data.sort_values(by='여성비율', ascending=False)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>구</th>
#       <th>인구수</th>
#       <th>남성</th>
#       <th>여성</th>
#       <th>내국인</th>
#       <th>남성내국인</th>
#       <th>여성내국인</th>
#       <th>외국인</th>
#       <th>남성외국인</th>
#       <th>여성외국인</th>
#       <th>세대당인구</th>
#       <th>고령자</th>
#       <th>외국인비율</th>
#       <th>고령비율</th>
#       <th>여성비율</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>14</th>
#       <td>마포구</td>
#       <td>385507</td>
#       <td>182627</td>
#       <td>202880</td>
#       <td>374691</td>
#       <td>178430</td>
#       <td>196261</td>
#       <td>10816</td>
#       <td>4197</td>
#       <td>6619</td>
# ...

# %%
raw_data.sort_values(by='고령비율', ascending=False)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>구</th>
#       <th>인구수</th>
#       <th>남성</th>
#       <th>여성</th>
#       <th>내국인</th>
#       <th>남성내국인</th>
#       <th>여성내국인</th>
#       <th>외국인</th>
#       <th>남성외국인</th>
#       <th>여성외국인</th>
#       <th>세대당인구</th>
#       <th>고령자</th>
#       <th>외국인비율</th>
#       <th>고령비율</th>
#       <th>여성비율</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>9</th>
#       <td>강북구</td>
#       <td>326063</td>
#       <td>159219</td>
#       <td>166844</td>
#       <td>322385</td>
#       <td>157769</td>
#       <td>164616</td>
#       <td>3678</td>
#       <td>1450</td>
#       <td>2228</td>
# ...

# %%
raw_data.sort_values(by='외국인비율', ascending=False)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>구</th>
#       <th>인구수</th>
#       <th>남성</th>
#       <th>여성</th>
#       <th>내국인</th>
#       <th>남성내국인</th>
#       <th>여성내국인</th>
#       <th>외국인</th>
#       <th>남성외국인</th>
#       <th>여성외국인</th>
#       <th>세대당인구</th>
#       <th>고령자</th>
#       <th>외국인비율</th>
#       <th>고령비율</th>
#       <th>여성비율</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>19</th>
#       <td>영등포구</td>
#       <td>404501</td>
#       <td>203696</td>
#       <td>200805</td>
#       <td>369003</td>
#       <td>183888</td>
#       <td>185115</td>
#       <td>35498</td>
#       <td>19808</td>
#       <td>15690</td>
# ...

# %%
raw_data.sort_values(by='세대당인구', ascending=True)
# Out:
#        구     인구수      남성      여성     내국인   남성내국인   여성내국인    외국인  남성외국인  여성외국인  \
# 21   관악구  522292  262428  259864  504445  253911  250534  17847   8517   9330
# 2     중구  135139   66582   68557  126082   62376   63706   9057   4206   4851
# 1    종로구  164348   79962   84386  154549   75749   78800   9799   4213   5586
# 3    용산구  245411  119985  125426  229909  111262  118647  15502   8723   6779
# 6   동대문구  364962  180381  184581  349308  174476  174832  15654   5905   9749
# 19  영등포구  403988  203472  200516  369128  184127  185001  34860  19345  15515
# 18   금천구  253344  129791  123553  234238  119023  115215  19106  10768   8338
# 14   마포구  385624  182905  202719  374742  178661  196081  10882   4244   6638
# 5    광진구  371671  180206  191465  357149  173946  183203  14522   6260   8262
# 9    강북구  327511  159853  167658  323862  158440  165422   3649   1413   2236
# 20   동작구  406715  197848  208867  394353  192215  202138  12362   5633   6729
# ...

# %%
raw_data.to_csv('pythonExam2018-1/exam/data/01. POP_result.csv', 
                sep=',', 
                encoding='utf-8')

# %%
# Out:
# ls: ../data/: No such file or directory
