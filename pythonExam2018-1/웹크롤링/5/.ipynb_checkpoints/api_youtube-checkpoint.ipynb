# %%
import requests
from pandas import *

vid = 'rLD3pxyhN_k'
video_url = []
comments_display = []
comments_original = []

url = "https://www.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId="+vid+"&key=AIzaSyC5h4yxw7GbCAq93imeVir6Hz_1IKGeTpM"

# %%
r = requests.get(url)
result = r.json()
#print(result)
for comment in result['items']:
    comment_to_insert = ''.join(comment['snippet']['topLevelComment']['snippet']['textDisplay'].replace('<br />',''))
    # if '배그' in comment_to_insert:
        
    comments_original.append(''.join(comment['snippet']['topLevelComment']['snippet']['textOriginal'].replace('\n',' ')))
    video_url.append('https://www.youtube.com/watch?v='+vid)
    
print(len(video_url))
print(len(comments_original))
# print(len(comments_display))
#  'comments_display' : comments_display,
dt_comments = DataFrame({'url' : video_url,
                         'comments_original' : comments_original})
# Out:
# 120
# 120

# %%
print(dt_comments)
# Out:
#                                      comments_original  \
# 0    저는 지금 일본 도쿄로 갈 준비를 하고있습니다. 곧 출발이거든요. 캬캬캬캬 도쿄는 ...
# 1                         저 블루님 보고 배워서 15시간만에 1등 했어요!!
# 2                                                ㅊ ㅂㅈㅌ
# 3                                        어떻게 할때마다 1등이냐
# 4                                               김블루 꿀잼
# 5                                       비와이 뭔데ㅋㅋㅋㅋㅋㅋㅋㅋ
# 6                                        블루님 핵쓰지마요 개잘핵
# 7                                                  핵이다
# 8                             인간 레드존 인가...(레드존이 필요없을듯)
# 9                                            인간 레드존ㅋㅋㅋ
# 10   클립영상       둥글게둥글게둥글게둥글게둥글게둥글게둥글게둥글게둥글게둥글게둥글게둥글...
# 11                                        미라마에서 에란겔 길리
# 12   이때는 아시아98위였고 지금은 아시아1위지.,대한민국 만세!!!!!!!🇰🇷🇰🇷🇰🇷🇰...
# 13                                      김불루님 배그대회나가봐요.
# 14                                         9분10초때관통아님?
# 15                   98위? 나처럼꼴지는돼야 고수지 솔까10 에들어야 꼴지됩니다
# ...
